# %%
import tft.ql.expr as ql
from tft.ql.util import *
from tft.client.meta import *
import json

# %%
client = MetaTFTClient()
comps = client.fetch(MetaTFTApis.COMPS_DATA)
set_data = client.fetch(MetaTFTApis.SET_DATA)
champ_items = client.fetch(MetaTFTApis.CHAMP_ITEMS)

# %%
q = ql.query(comps)
q2 = ql.query(set_data)
q3 = ql.query(champ_items)

# %%
# All item data.
# Splay displays nested fields for a query.
# [X] means its a list and the first one is picked.
q2.idx('items.0').splay()
# Out:
# apiName
#   TFT_Item_RabadonsDeathcap
# associatedTraits
#   [0]
# composition
#   [2]
#     TFT_Item_NeedlesslyLargeRod
# desc
#
# effects
#   AP
#     50
#   BonusDamage
#     0.20000000298023224
#   {1543aa48}
#     0.20000000298023224
# from
#   None
# icon
#   ASSETS/Maps/Particles/TFT/Item_Icons/Standard/Rabadons_Deathcap.tex
# id
#   None
# incompatibleTraits
#   [0]
# name
#   Rabadon's Deathcap
# unique
#   False
# en_name
#   Rabadon's Deathcap
# tags
#   [0]

# %%
# Buildable items.
buildable_items = q2.idx('items').filter(ql.idx('composition').len().eq(2))
# buildable_items.map(ql.idx('apiName')).vals().eval() # Names.
buildable_items.map(ql.idx('en_name')).eval()
# Out:
# ["Rabadon's Deathcap",
#  'Infinity Edge',
#  "Protector's Vow",
#  'Redemption',
#  'Sugarcraft Emblem',
#  'Honeymancy Emblem',
#  'Faerie Emblem',
#  'Frost Emblem',
#  'Witchcraft Emblem',
#  'Eldritch Emblem',
#  'Pyro Emblem',
#  'Portal Emblem',
#  "Thief's Gloves",
#  "Guinsoo's Rageblade",
#  'Ionic Spark',
#  "Sterak's Gage",
#  "Dragon's Claw",
#  'Guardbreaker',
#  'Gargoyle Stoneplate',
#  'Bramble Vest',
#  'Giant Slayer',
#  'Sunfire Cape',
#  'Hand Of Justice',
#  'Edge of Night',
#  "Titan's Resolve",
#  "Runaan's Hurricane",
#  'Bloodthirster',
#  "Archangel's Staff",
#  'Spear of Shojin',
#  'Evenshroud',
#  "Nashor's Tooth",
#  'Morellonomicon',
#  'Red Buff',
#  'Crownguard',
#  'Adaptive Helm',
#  'Blue Buff',
#  'Last Whisper',
#  'Jeweled Gauntlet',
#  'Steadfast Heart',
#  "Tactician's Crown",
#  'Quicksilver',
#  'Deathblade',
#  "Warmog's Armor",
#  'Statikk Shiv',
#  'Hextech Gunblade']

# %%
# Base components names.
component_names = buildable_items.map(ql.idx('composition')).flatten().uniq().eval()
component_items = q2.idx('items').filter(ql.idx('apiName').in_set(component_names))
component_names
# Out:
# ['TFT_Item_Spatula',
#  'TFT_Item_RecurveBow',
#  'TFT_Item_TearOfTheGoddess',
#  'TFT_Item_NegatronCloak',
#  'TFT_Item_GiantsBelt',
#  'TFT_Item_BFSword',
#  'TFT_Item_SparringGloves',
#  'TFT_Item_NeedlesslyLargeRod',
#  'TFT_Item_ChainVest']

# %%
# Emblem items.
emblems = q2.idx('items').filter(ql.idx('apiName').contains('Emblem'))
emblems.map(ql.idx('apiName')).eval()
# Out:
# ['TFT12_Item_SugarcraftEmblemItem',
#  'TFT12_Item_BlasterEmblemItem',
#  'TFT12_Item_VanguardEmblemItem',
#  'TFT12_Item_ScholarEmblemItem',
#  'TFT12_Item_ChronoEmblemItem',
#  'TFT12_Item_HoneymancyEmblemItem',
#  'TFT12_Item_PreserverEmblemItem',
#  'TFT12_Item_ArcanaEmblemItem',
#  'TFT12_Item_MageEmblemItem',
#  'TFT12_Item_FaerieEmblemItem',
#  'TFT12_Item_BastionEmblemItem',
#  'TFT12_Item_WarriorEmblemItem',
#  'TFT12_Item_IncantorEmblemItem',
#  'TFT12_Item_FrostEmblemItem',
#  'TFT12_Item_WitchcraftEmblemItem',
#  'TFT12_Item_MultistrikerEmblemItem',
#  'TFT12_Item_ShapeshifterEmblemItem',
#  'TFT12_Item_EldritchEmblemItem',
#  'TFT12_Item_PyroEmblemItem',
#  'TFT12_Item_HunterEmblemItem',
#  'TFT12_Item_PortalEmblemItem']

# %%
# TFT set
q.idx('tft_set').eval()
# Out:
# 'TFTSet12'

# %%
champions = q2.idx('units').filter(ql.idx('traits').len().gt(0))
champions.map(ql.idx('en_name')).eval()
# Out:
# ['Zilean',
#  'Twitch',
#  'Warwick',
#  'Hwei',
#  'Diana',
#  'Jax',
#  'Vex',
#  'Smolder',
#  'Karma',
#  'Camille',
#  'Blitzcrank',
#  'Elise',
#  'Jayce',
#  'Tristana',
#  'Ashe',
#  'Zoe',
#  'Nilah',
#  'Kassadin',
#  "Kog'Maw",
#  'Cassiopeia',
#  'Syndra',
#  'Nunu',
#  'Katarina',
#  'Hecarim',
#  'Neeko',
#  'Ezreal',
#  'Jinx',
#  'Veigar',
#  'Bard',
#  'Lillia',
#  'Mordekaiser',
#  'Fiora',
#  'Gwen',
#  'Rakan',
#  'Tahm Kench',
#  'Kalista',
#  'Ryze',
#  'Nami',
#  'Briar',
#  'Morgana',
#  'Xerath',
#  'Milio',
#  'Norra & Yuumi',
#  'Nomsy',
#  'Varus',
#  'Nasus',
#  'Akali',
#  'Taric',
#  'Galio',
#  'Shen',
#  'Shyvana',
#  'Poppy',
#  'Rumble',
#  'Ziggs',
#  'Swain',
#  'Ahri',
#  'Soraka',
#  'Seraphine',
#  'Olaf',
#  'Wukong']

# %%
champ_name_map = champions.map(ql.idx('en_name'), ql.idx('apiName')).eval()
component_item_name_map = component_items.map(ql.idx('en_name'), ql.idx('apiName')).eval()
buildable_item_name_map = buildable_items.map(ql.idx('en_name'), ql.idx('apiName')).eval()
buildable_item_name_map
# Out:
# {'TFT_Item_RabadonsDeathcap': "Rabadon's Deathcap",
#  'TFT_Item_InfinityEdge': 'Infinity Edge',
#  'TFT_Item_FrozenHeart': "Protector's Vow",
#  'TFT_Item_Redemption': 'Redemption',
#  'TFT12_Item_SugarcraftEmblemItem': 'Sugarcraft Emblem',
#  'TFT12_Item_HoneymancyEmblemItem': 'Honeymancy Emblem',
#  'TFT12_Item_FaerieEmblemItem': 'Faerie Emblem',
#  'TFT12_Item_FrostEmblemItem': 'Frost Emblem',
#  'TFT12_Item_WitchcraftEmblemItem': 'Witchcraft Emblem',
#  'TFT12_Item_EldritchEmblemItem': 'Eldritch Emblem',
#  'TFT12_Item_PyroEmblemItem': 'Pyro Emblem',
#  'TFT12_Item_PortalEmblemItem': 'Portal Emblem',
#  'TFT_Item_ThiefsGloves': "Thief's Gloves",
#  'TFT_Item_GuinsoosRageblade': "Guinsoo's Rageblade",
#  'TFT_Item_IonicSpark': 'Ionic Spark',
#  'TFT_Item_SteraksGage': "Sterak's Gage",
#  'TFT_Item_DragonsClaw': "Dragon's Claw",
#  'TFT_Item_PowerGauntlet': 'Guardbreaker',
#  'TFT_Item_GargoyleStoneplate': 'Gargoyle Stoneplate',
#  'TFT_Item_BrambleVest': 'Bramble Vest',
#  'TFT_Item_MadredsBloodrazor': 'Giant Slayer',
#  'TFT_Item_RedBuff': 'Sunfire Cape',
#  'TFT_Item_UnstableConcoction': 'Hand Of Justice',
#  'TFT_Item_GuardianAngel': 'Edge of Night',
#  'TFT_Item_TitansResolve': "Titan's Resolve",
#  'TFT_Item_RunaansHurricane': "Runaan's Hurricane",
#  'TFT_Item_Bloodthirster': 'Bloodthirster',
#  'TFT_Item_ArchangelsStaff': "Archangel's Staff",
#  'TFT_Item_SpearOfShojin': 'Spear of Shojin',
#  'TFT_Item_SpectralGauntlet': 'Evenshroud',
#  'TFT_Item_Leviathan': "Nashor's Tooth",
#  'TFT_Item_Morellonomicon': 'Morellonomicon',
#  'TFT_Item_RapidFireCannon': 'Red Buff',
#  'TFT_Item_Crownguard': 'Crownguard',
#  'TFT_Item_AdaptiveHelm': 'Adaptive Helm',
#  'TFT_Item_BlueBuff': 'Blue Buff',
#  'TFT_Item_LastWhisper': 'Last Whisper',
#  'TFT_Item_JeweledGauntlet': 'Jeweled Gauntlet',
#  'TFT_Item_NightHarvester': 'Steadfast Heart',
#  'TFT_Item_ForceOfNature': "Tactician's Crown",
#  'TFT_Item_Quicksilver': 'Quicksilver',
#  'TFT_Item_Deathblade': 'Deathblade',
#  'TFT_Item_WarmogsArmor': "Warmog's Armor",
#  'TFT_Item_StatikkShiv': 'Statikk Shiv',
#  'TFT_Item_HextechGunblade': 'Hextech Gunblade'}

# %%
comp_clusters = q.idx('results.data.cluster_details')
comp_clusters.idx('0').eval()
# Out:
# {'Cluster': 0,
#  'centroid': [0.331,
#   0.0685,
#   0.0118,
#   0.0818,
#   1.0363,
#   0.0318,
#   0.042,
#   0.0792,
#   0.7249,
#   0.0074,
#   0.0182,
#   0.0346,
#   0.0367,
#   0.0177,
#   1.439,
#   0.0241,
#   0.0096,
#   0.0086,
#   0.1261,
#   0.1139,
#   0.0671,
#   0.0288,
#   0.0306,
#   2.1067,
#   0.7189,
#   0.1209,
#   0.0243,
#   0.0835,
#   0.0278,
#   0.0861,
#   0.0241,
#   0.0105,
#   0.0165,
#   0.0862,
#   4.0443,
#   0.1909,
#   0.6727,
#   0.0719,
#   0.06,
#   0.1207,
#   0.0191,
#   1.5702,
#   0.0256,
#   0.0622,
#   0.008,
#   0.0213,
#   0.0369,
#   0.2147,
#   1.4972,
#   0.0489,
#   0.0148,
#   0.1314,
#   1.9537,
#   0.0281,
#   0.0101,
#   0,
#   0.0385,
#   0.2782,
#   0.0503,
#   0.6922,
#   0.0535,
#   0.1421,
#   0.0111,
#   0.4206,
#   3.3397,
#   0.0548,
#   0.0281,
#   0.0111,
#   0.0084,
#   0.1604,
#   0.0368,
#   2.316,
#   0.2465,
#   0.0696,
#   0.0495,
#   0.0799,
#   0.1034,
#   0.075,
#   0.1786,
#   0.1561,
#   0.0381,
#   0.0276,
#   0.1578,
#   0.0221,
#   0.1619,
#   0,
#   0,
#   0,
#   0,
#   0,
#   10,
#   0,
#   0,
#   0],
#  'units_string': 'TFT12_Blitzcrank, TFT12_Hecarim, TFT12_KogMaw, TFT12_Nunu, TFT12_Shen, TFT12_Taric, TFT12_Veigar, TFT12_Ziggs',
#  'traits_string': 'TFT12_Bastion_2, TFT12_Honeymancy_2',
#  'name': [{'name': 'TFT12_Augment_NunuCarry',
#    'type': 'augment',
#    'score': 17.7134}],
#  'name_string': 'TFT12_Augment_NunuCarry',
#  'top_headliner': [],
#  'overall': {'count': 56834, 'avg': 4.4652},
#  'stars': ['TFT12_Nunu',
#   'TFT12_Blitzcrank',
#   'TFT12_Ziggs',
#   'TFT12_KogMaw',
#   'TFT12_Veigar',
#   'TFT12_Rumble',
#   'TFT12_Ahri',
#   'TFT12_Tristana',
#   'TFT12_Cassiopeia',
#   'TFT12_Wukong',
#   'TFT12_Syndra'],
#  'stars_4': [],
#  'builds': [{'cluster': '0',
#    'count': 17068,
#    'avg': 4.0132,
#    'unit': 'TFT12_Nunu',
#    'buildName': ['TFT_Item_ArchangelsStaff',
#     'TFT_Item_Bloodthirster',
#     'TFT_Item_WarmogsArmor'],
#    'build': [],
#    'num_items': 3,
#    'score': 0.5836,
#    'place_change': -0.452,
#    'unit_numitems_count': 50452},
#   {'cluster': '0',
#    'count': 1085,
#    'avg': 3.5558,
#    'unit': 'TFT12_Veigar',
#    'buildName': ['TFT_Item_BlueBuff',
#     'TFT_Item_Leviathan',
#     'TFT_Item_RabadonsDeathcap'],
#    'build': [],
#    'num_items': 3,
#    'score': 0.2588,
#    'place_change': -0.909,
#    'unit_numitems_count': 18821},
#   {'cluster': '0',
#    'count': 2854,
#    'avg': 3.5809,
#    'unit': 'TFT12_KogMaw',
#    'buildName': ['TFT_Item_GuinsoosRageblade',
#     'TFT_Item_InfinityEdge',
#     'TFT_Item_LastWhisper'],
#    'build': [],
#    'num_items': 3,
#    'score': 0.2866,
#    'place_change': -0.884,
#    'unit_numitems_count': 17887},
#   {'cluster': '0',
#    'count': 168,
#    'avg': 4.0536,
#    'unit': 'TFT12_Shen',
#    'buildName': ['TFT_Item_GargoyleStoneplate', 'TFT_Item_RedBuff'],
#    'build': [],
#    'num_items': 2,
#    'score': 0.0124,
#    'place_change': -0.412,
#    'unit_numitems_count': 10236}],
#  'build_items': {'TFT_Item_ArchangelsStaff': {'itemNames': 'TFT_Item_ArchangelsStaff',
#    'count': 43794,
#    'avg': 4.28,
#    'pcnt': 0.77056},
#   'TFT_Item_WarmogsArmor': {'itemNames': 'TFT_Item_WarmogsArmor',
#    'count': 43675,
#    'avg': 4.169,
#    'pcnt': 0.76847},
#   'TFT_Item_Bloodthirster': {'itemNames': 'TFT_Item_Bloodthirster',
#    'count': 37997,
#    'avg': 4.1945,
#    'pcnt': 0.66856},
#   'TFT_Item_GuinsoosRageblade': {'itemNames': 'TFT_Item_GuinsoosRageblade',
#    'count': 27430,
#    'avg': 4.1362,
#    'pcnt': 0.48263},
#   'TFT_Item_GargoyleStoneplate': {'itemNames': 'TFT_Item_GargoyleStoneplate',
#    'count': 25315,
#    'avg': 4.2914,
#    'pcnt': 0.44542},
#   'TFT_Item_InfinityEdge': {'itemNames': 'TFT_Item_InfinityEdge',
#    'count': 17072,
#    'avg': 4.0039,
#    'pcnt': 0.30038},
#   'TFT_Item_LastWhisper': {'itemNames': 'TFT_Item_LastWhisper',
#    'count': 16518,
#    'avg': 3.9203,
#    'pcnt': 0.29064},
#   'TFT_Item_BlueBuff': {'itemNames': 'TFT_Item_BlueBuff',
#    'count': 15038,
#    'avg': 4.0374,
#    'pcnt': 0.2646},
#   'TFT_Item_Leviathan': {'itemNames': 'TFT_Item_Leviathan',
#    'count': 14914,
#    'avg': 3.9724,
#    'pcnt': 0.26241},
#   'TFT_Item_RedBuff': {'itemNames': 'TFT_Item_RedBuff',
#    'count': 13588,
#    'avg': 3.9374,
#    'pcnt': 0.23908},
#   'TFT_Item_RabadonsDeathcap': {'itemNames': 'TFT_Item_RabadonsDeathcap',
#    'count': 9994,
#    'avg': 3.8606,
#    'pcnt': 0.17585}},
#  'top_itemNames': [{'itemNames': 'TFT_Item_ArchangelsStaff',
#    'count': 43794,
#    'avg': 4.28,
#    'pcnt': 0.77056},
#   {'itemNames': 'TFT_Item_WarmogsArmor',
#    'count': 43675,
#    'avg': 4.169,
#    'pcnt': 0.76847},
#   {'itemNames': 'TFT_Item_Bloodthirster',
#    'count': 37997,
#    'avg': 4.1945,
#    'pcnt': 0.66856}],
#  'top_items': [],
#  'trends': [{'day': '2024-08-17T00:00:00.000Z',
#    'count': 90,
#    'avg': 4.1556,
#    'pick': 0.007470739603220719},
#   {'day': '2024-08-18T00:00:00.000Z',
#    'count': 79,
#    'avg': 4.5063,
#    'pick': 0.0061733218723138234},
#   {'day': '2024-08-19T00:00:00.000Z',
#    'count': 138,
#    'avg': 3.9493,
#    'pick': 0.006875249103228378},
#   {'day': '2024-08-20T00:00:00.000Z',
#    'count': 15146,
#    'avg': 4.5485,
#    'pick': 0.0056118826966085646},
#   {'day': '2024-08-21T00:00:00.000Z',
#    'count': 18402,
#    'avg': 4.4538,
#    'pick': 0.005860580478362477},
#   {'day': '2024-08-22T00:00:00.000Z',
#    'count': 23392,
#    'avg': 4.4918,
#    'pick': 0.00595524048178588},
#   {'day': '2024-08-23T00:00:00.000Z',
#    'count': 33853,
#    'avg': 4.4474,
#    'pick': 0.005749230758257185},
#   {'day': '2024-08-24T00:00:00.000Z',
#    'count': 972,
#    'avg': 4.3827,
#    'pick': 0.005376344086021506}],
#  'top_augments': [{'aug': 'TFT12_Augment_NunuCarry',
#    'count': 50336,
#    'avg': 4.473,
#    'pcnt': 0.88567}],
#  'diff_pick': -0.009,
#  'diff_place': 0.042,
#  'difficulty': -0.051,
#  'levelling': 'lvl 6'}

# %%
q.idx('results.data').splay(0)
# Out:
# cluster_id
# tft_set
# cluster_details
# portals

# %%
"""
> clr            # Clear your current composition
> top            # Give me best compositions right now
> top zil        # Give me best compositions with Zilean.
> early zil      # Give me best early compositions with Zilean
> bi zil         # Give me best items for Zilean
> add zil twt ww # Stores Zilean, Twitch, and Warwick as part of your team.
> padd olaf      # If I add Olaf, what is the best composition?
> q Zilean       # Give me aliases for Zilean (zil, zi, Zilean)
"""
# Out:
# '\n> clr            # Clear your current composition\n> top            # Give me best compositions right now\n> top zil        # Give me best compositions with Zilean.\n> early zil      # Give me best early compositions with Zilean\n> bi zil         # Give me best items for Zilean\n> add zil twt ww # Stores Zilean, Twitch, and Warwick as part of your team.\n> padd olaf      # If I add Olaf, what is the best composition?\n> q Zilean       # Give me aliases for Zilean (zil, zi, Zilean)\n'

# %%
q2.idx('items').filter(ql.idx('composition').len().eq(2)).idx('0').sub({
    'en_name': ql.idx('en_name'),
    'effects': ql.idx('effects.AP')
}).eval()
# a = {
#     "a": [
#         {
#             "name": "Bob",
#             "eyes": "blue"
#         },
#         {
#             "name": "Joe",
#             "eyes": "brown"
#         }
#     ]
# }

# ql.query(a).idx("a").filter(ql.idx('eyes').eq('blue')).idx('name').eval()
# Out:
# {'en_name': "Rabadon's Deathcap", 'effects': 50}

# %%
# champions.filter(ql.idx('traits').contains('Frost')).map(ql.idx('en_name')).eval()
champs = champions.map(ql.idx('apiName')).eval()
for champ in champs:
    print(champ)
# Out:
# ['TFT12_Zilean',
#  'TFT12_Twitch',
#  'TFT12_Warwick',
#  'TFT12_Hwei',
#  'TFT12_Diana',
#  'TFT12_Jax',
#  'TFT12_Vex',
#  'TFT12_Smolder',
#  'TFT12_Karma',
#  'TFT12_Camille',
#  'TFT12_Blitzcrank',
#  'TFT12_Elise',
#  'TFT12_Jayce',
#  'TFT12_Tristana',
#  'TFT12_Ashe',
#  'TFT12_Zoe',
#  'TFT12_Nilah',
#  'TFT12_Kassadin',
#  'TFT12_KogMaw',
#  'TFT12_Cassiopeia',
#  'TFT12_Syndra',
#  'TFT12_Nunu',
#  'TFT12_Katarina',
#  'TFT12_Hecarim',
#  'TFT12_Neeko',
#  'TFT12_Ezreal',
#  'TFT12_Jinx',
#  'TFT12_Veigar',
#  'TFT12_Bard',
#  'TFT12_Lillia',
#  'TFT12_Mordekaiser',
#  'TFT12_Fiora',
#  'TFT12_Gwen',
#  'TFT12_Rakan',
#  'TFT12_TahmKench',
#  'TFT12_Kalista',
#  'TFT12_Ryze',
#  'TFT12_Nami',
#  'TFT12_Briar',
#  'TFT12_Morgana',
#  'TFT12_Xerath',
#  'TFT12_Milio',
#  'TFT12_Norra',
#  'TFT12_Nomsy',
#  'TFT12_Varus',
#  'TFT12_Nasus',
#  'TFT12_Akali',
#  'TFT12_Taric',
#  'TFT12_Galio',
#  'TFT12_Shen',
#  'TFT12_Shyvana',
#  'TFT12_Poppy',
#  'TFT12_Rumble',
#  'TFT12_Ziggs',
#  'TFT12_Swain',
#  'TFT12_Ahri',
#  'TFT12_Soraka',
#  'TFT12_Seraphine',
#  'TFT12_Olaf',
#  'TFT12_Wukong']

# %%
def avg_place(places: Any) -> Any:
    tot = sum(places)
    return sum((i+1) * x / tot for i, x in enumerate(places))

q3.idx('TFT12_Zilean.items').filter(ql.idx('itemName').in_set(buildable_item_name_map)).map(ql.sub({
    'name': ql.idx('itemName').replace(buildable_item_name_map),
    "avg_place": ql.idx('places').unary(avg_place),
    "games": ql.idx('places').unary(sum)
})).eval()
# .sort_by(ql.idx('games'), True).filter(ql.idx('games').gt(100)).top(10).eval()
# Out:
# [{'name': 'Eldritch Emblem', 'avg_place': 4.216091954022988, 'games': 435},
#  {'name': 'Faerie Emblem', 'avg_place': 3.9621578099838968, 'games': 1242},
#  {'name': 'Honeymancy Emblem', 'avg_place': 4.162303664921466, 'games': 382},
#  {'name': 'Portal Emblem', 'avg_place': 4.02292576419214, 'games': 916},
#  {'name': 'Pyro Emblem', 'avg_place': 3.827777777777778, 'games': 1260},
#  {'name': 'Sugarcraft Emblem', 'avg_place': 4.346960167714885, 'games': 1908},
#  {'name': 'Witchcraft Emblem', 'avg_place': 3.412140575079872, 'games': 2191},
#  {'name': 'Adaptive Helm', 'avg_place': 3.9738065716057034, 'games': 6452},
#  {'name': "Archangel's Staff", 'avg_place': 4.232052211747643, 'games': 6895},
#  {'name': 'Bloodthirster', 'avg_place': 4.149122807017544, 'games': 114},
#  {'name': 'Blue Buff', 'avg_place': 4.1309523809523805, 'games': 2940},
#  {'name': 'Bramble Vest', 'avg_place': 4.103092783505154, 'games': 97},
#  {'name': 'Crownguard', 'avg_place': 4.006756756756757, 'games': 148},
#  {'name': 'Deathblade', 'avg_place': 4.093023255813954, 'games': 129},
#  {'name': "Dragon's Claw", 'avg_place': 3.7142857142857144, 'games': 119},
#  {'name': "Tactician's Crown", 'avg_place': 3.6958965711073635, 'games': 1779},
#  {'name': "Protector's Vow", 'avg_place': 3.6218905472636815, 'games': 201},
#  {'name': 'Gargoyle Stoneplate', 'avg_place': 4.099009900990099, 'games': 101},
#  {'name': 'Edge of Night', 'avg_place': 3.4466019417475726, 'games': 206},
#  {'name': "Guinsoo's Rageblade",
#   'avg_place': 4.445202020202021,
#   'games': 3960},
#  {'name': 'Hextech Gunblade', 'avg_place': 4.172535211267606, 'games': 852},
#  {'name': 'Infinity Edge', 'avg_place': 4.449612403100775, 'games': 258},
#  {'name': 'Ionic Spark', 'avg_place': 3.7883211678832116, 'games': 137},
#  {'name': 'Jeweled Gauntlet', 'avg_place': 4.265662490002666, 'games': 7502},
#  {'name': 'Last Whisper', 'avg_place': 4.134464751958225, 'games': 766},
#  {'name': "Nashor's Tooth", 'avg_place': 4.168542905692439, 'games': 9416},
#  {'name': 'Giant Slayer', 'avg_place': 4.0929425376012345, 'games': 5186},
#  {'name': 'Morellonomicon', 'avg_place': 4.2192021043402015, 'games': 4562},
#  {'name': 'Steadfast Heart', 'avg_place': 3.752808988764045, 'games': 89},
#  {'name': 'Guardbreaker', 'avg_place': 4.052557105316353, 'games': 4947},
#  {'name': 'Quicksilver', 'avg_place': 3.6083650190114067, 'games': 263},
#  {'name': "Rabadon's Deathcap", 'avg_place': 4.156939040207523, 'games': 6168},
#  {'name': 'Red Buff', 'avg_place': 4.119821978774392, 'games': 2921},
#  {'name': 'Sunfire Cape', 'avg_place': 3.8869565217391306, 'games': 115},
#  {'name': 'Redemption', 'avg_place': 3.736024844720497, 'games': 322},
#  {'name': "Runaan's Hurricane", 'avg_place': 4.035264483627204, 'games': 397},
#  {'name': 'Spear of Shojin', 'avg_place': 4.298378450817475, 'games': 14924},
#  {'name': 'Evenshroud', 'avg_place': 3.5277777777777777, 'games': 72},
#  {'name': 'Statikk Shiv', 'avg_place': 3.8538471131063723, 'games': 8019},
#  {'name': "Sterak's Gage", 'avg_place': 4.089285714285714, 'games': 56},
#  {'name': "Thief's Gloves", 'avg_place': 4.023215608792294, 'games': 4049},
#  {'name': "Titan's Resolve", 'avg_place': 4.048192771084337, 'games': 83},
#  {'name': 'Hand Of Justice', 'avg_place': 4.017699115044247, 'games': 339},
#  {'name': "Warmog's Armor", 'avg_place': 4.256880733944954, 'games': 109}]

# %%
q3.idx('TFT12_Zilean.builds').map(ql.sub({
    'items': ql.idx('buildNames').split('|'),
    'avg_place': ql.idx('places').unary(avg_place),
    'games': ql.idx('places').unary(sum)
})).filter(ql.all([
    ql.idx('items').map(ql.in_set(buildable_item_name_map)).unary(all),
    ql.idx('items').len().eq(3)
])).sort_by(ql.idx('games'), True).to_pandas()

# q3.idx('TFT12_Zilean.builds').map(ql.idx('buildNames').split('|')).eval()
# Out:
#                                                  items  avg_place  games
# 0    [TFT_Item_JeweledGauntlet, TFT_Item_Leviathan,...   4.574374    679
# 1    [TFT_Item_ArchangelsStaff, TFT_Item_Leviathan,...   4.425150    334
# 2    [TFT_Item_Leviathan, TFT_Item_RabadonsDeathcap...   4.485401    274
# 3    [TFT_Item_GuinsoosRageblade, TFT_Item_JeweledG...   4.720000    125
# 4    [TFT_Item_ArchangelsStaff, TFT_Item_JeweledGau...   4.878049    123
# ..                                                 ...        ...    ...
# 147  [TFT_Item_BlueBuff, TFT_Item_Morellonomicon, T...   3.090909     11
# 148  [TFT_Item_JeweledGauntlet, TFT_Item_Leviathan,...   3.727273     11
# 149  [TFT_Item_JeweledGauntlet, TFT_Item_Morellonom...   3.636364     11
# 150  [TFT_Item_Leviathan, TFT_Item_Leviathan, TFT_I...   3.636364     11
# 151  [TFT_Item_Leviathan, TFT_Item_RabadonsDeathcap...   3.000000     11
#
# [152 rows x 3 columns]
