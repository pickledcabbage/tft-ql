# %%
import tft.ql.expr as ql
from tft.ql.util import *
from tft.client.meta import *
import json

# %%
client = MetaTFTClient()
comps = client.fetch(MetaTFTApis.COMPS_DATA)
set_data = client.fetch(MetaTFTApis.SET_DATA)
champ_items = client.fetch(MetaTFTApis.CHAMP_ITEMS)

# %%
q = ql.query(comps)
q2 = ql.query(set_data)
q3 = ql.query(champ_items)

# %%
# All item data.
# Splay displays nested fields for a query.
# [X] means its a list and the first one is picked.
q2.idx('items.0').splay()
# Out:
# apiName
#   TFT_Item_RabadonsDeathcap
# associatedTraits
#   [0]
# composition
#   [2]
#     TFT_Item_NeedlesslyLargeRod
# desc
#
# effects
#   AP
#     50
#   BonusDamage
#     0.20000000298023224
#   {1543aa48}
#     0.20000000298023224
# from
#   None
# icon
#   ASSETS/Maps/Particles/TFT/Item_Icons/Standard/Rabadons_Deathcap.tex
# id
#   None
# incompatibleTraits
#   [0]
# name
#   Rabadon's Deathcap
# unique
#   False
# en_name
#   Rabadon's Deathcap
# tags
#   [0]

# %%
# Buildable items.
buildable_items = q2.idx('items').filter(ql.idx('composition').len().eq(2))
# buildable_items.map(ql.idx('apiName')).vals().eval() # Names.
buildable_items.map(ql.idx('en_name')).eval()
# Out:
# {0: "Rabadon's Deathcap",
#  1: 'Infinity Edge',
#  2: "Protector's Vow",
#  3: 'Redemption',
#  4: 'Sugarcraft Emblem',
#  5: 'Honeymancy Emblem',
#  6: 'Faerie Emblem',
#  7: 'Frost Emblem',
#  8: 'Witchcraft Emblem',
#  9: 'Eldritch Emblem',
#  10: 'Pyro Emblem',
#  11: 'Portal Emblem',
#  12: "Thief's Gloves",
#  13: "Guinsoo's Rageblade",
#  14: 'Ionic Spark',
#  15: "Sterak's Gage",
#  16: "Dragon's Claw",
#  17: 'Guardbreaker',
#  18: 'Gargoyle Stoneplate',
#  19: 'Bramble Vest',
#  20: 'Giant Slayer',
#  21: 'Sunfire Cape',
#  22: 'Hand Of Justice',
#  23: 'Edge of Night',
#  24: "Titan's Resolve",
#  25: "Runaan's Hurricane",
#  26: 'Bloodthirster',
#  27: "Archangel's Staff",
#  28: 'Spear of Shojin',
#  29: 'Evenshroud',
#  30: "Nashor's Tooth",
#  31: 'Morellonomicon',
#  32: 'Red Buff',
#  33: 'Crownguard',
#  34: 'Adaptive Helm',
#  35: 'Blue Buff',
#  36: 'Last Whisper',
#  37: 'Jeweled Gauntlet',
#  38: 'Steadfast Heart',
#  39: "Tactician's Crown",
#  40: 'Quicksilver',
#  41: 'Deathblade',
#  42: "Warmog's Armor",
#  43: 'Statikk Shiv',
#  44: 'Hextech Gunblade'}

# %%
# Base components names.
component_names = buildable_items.map(ql.idx('composition')).vals().flatten().uniq().eval()
component_items = q2.idx('items').filter(ql.idx('apiName').in_set(component_names))
component_names
# Out:
# ['TFT_Item_Spatula',
#  'TFT_Item_NegatronCloak',
#  'TFT_Item_ChainVest',
#  'TFT_Item_BFSword',
#  'TFT_Item_NeedlesslyLargeRod',
#  'TFT_Item_SparringGloves',
#  'TFT_Item_RecurveBow',
#  'TFT_Item_TearOfTheGoddess',
#  'TFT_Item_GiantsBelt']

# %%
# Emblem items.
emblems = q2.idx('items').filter(ql.idx('apiName').contains('Emblem'))
emblems.map(ql.idx('apiName')).vals().eval()
# Out:
# ['TFT12_Item_SugarcraftEmblemItem',
#  'TFT12_Item_BlasterEmblemItem',
#  'TFT12_Item_VanguardEmblemItem',
#  'TFT12_Item_ScholarEmblemItem',
#  'TFT12_Item_ChronoEmblemItem',
#  'TFT12_Item_HoneymancyEmblemItem',
#  'TFT12_Item_PreserverEmblemItem',
#  'TFT12_Item_ArcanaEmblemItem',
#  'TFT12_Item_MageEmblemItem',
#  'TFT12_Item_FaerieEmblemItem',
#  'TFT12_Item_BastionEmblemItem',
#  'TFT12_Item_WarriorEmblemItem',
#  'TFT12_Item_IncantorEmblemItem',
#  'TFT12_Item_FrostEmblemItem',
#  'TFT12_Item_WitchcraftEmblemItem',
#  'TFT12_Item_MultistrikerEmblemItem',
#  'TFT12_Item_ShapeshifterEmblemItem',
#  'TFT12_Item_EldritchEmblemItem',
#  'TFT12_Item_PyroEmblemItem',
#  'TFT12_Item_HunterEmblemItem',
#  'TFT12_Item_PortalEmblemItem']

# %%
# TFT set
q.idx('tft_set').eval()
# Out:
# 'TFTSet12'

# %%
champions = q2.idx('units').filter(ql.idx('traits').len().gt(0))
champions.map(ql.idx('en_name')).eval()
# Out:
# {0: 'Zilean',
#  1: 'Twitch',
#  2: 'Warwick',
#  3: 'Hwei',
#  4: 'Diana',
#  5: 'Jax',
#  6: 'Vex',
#  7: 'Smolder',
#  8: 'Karma',
#  9: 'Camille',
#  10: 'Blitzcrank',
#  11: 'Elise',
#  12: 'Jayce',
#  13: 'Tristana',
#  14: 'Ashe',
#  15: 'Zoe',
#  16: 'Nilah',
#  17: 'Kassadin',
#  18: "Kog'Maw",
#  19: 'Cassiopeia',
#  20: 'Syndra',
#  21: 'Nunu',
#  22: 'Katarina',
#  23: 'Hecarim',
#  24: 'Neeko',
#  25: 'Ezreal',
#  26: 'Jinx',
#  27: 'Veigar',
#  28: 'Bard',
#  29: 'Lillia',
#  30: 'Mordekaiser',
#  31: 'Fiora',
#  32: 'Gwen',
#  33: 'Rakan',
#  34: 'Tahm Kench',
#  35: 'Kalista',
#  36: 'Ryze',
#  37: 'Nami',
#  38: 'Briar',
#  39: 'Morgana',
#  40: 'Xerath',
#  41: 'Milio',
#  42: 'Norra & Yuumi',
#  43: 'Nomsy',
#  44: 'Varus',
#  45: 'Nasus',
#  46: 'Akali',
#  47: 'Taric',
#  48: 'Galio',
#  49: 'Shen',
#  50: 'Shyvana',
#  51: 'Poppy',
#  52: 'Rumble',
#  53: 'Ziggs',
#  54: 'Swain',
#  55: 'Ahri',
#  56: 'Soraka',
#  57: 'Seraphine',
#  58: 'Olaf',
#  59: 'Wukong'}

# %%
champ_name_map = champions.map(ql.idx('en_name'), ql.idx('apiName')).eval()
component_item_name_map = component_items.map(ql.idx('en_name'), ql.idx('apiName')).eval()
buildable_item_name_map = buildable_items.map(ql.idx('en_name'), ql.idx('apiName')).eval()

# %%
comp_clusters = q.idx('results.data.cluster_details')
comp_clusters.idx('0').eval()
# Out:
# {'Cluster': 0,
#  'centroid': [0.331,
#   0.0685,
#   0.0118,
#   0.0818,
#   1.0363,
#   0.0318,
#   0.042,
#   0.0792,
#   0.7249,
#   0.0074,
#   0.0182,
#   0.0346,
#   0.0367,
#   0.0177,
#   1.439,
#   0.0241,
#   0.0096,
#   0.0086,
#   0.1261,
#   0.1139,
#   0.0671,
#   0.0288,
#   0.0306,
#   2.1067,
#   0.7189,
#   0.1209,
#   0.0243,
#   0.0835,
#   0.0278,
#   0.0861,
#   0.0241,
#   0.0105,
#   0.0165,
#   0.0862,
#   4.0443,
#   0.1909,
#   0.6727,
#   0.0719,
#   0.06,
#   0.1207,
#   0.0191,
#   1.5702,
#   0.0256,
#   0.0622,
#   0.008,
#   0.0213,
#   0.0369,
#   0.2147,
#   1.4972,
#   0.0489,
#   0.0148,
#   0.1314,
#   1.9537,
#   0.0281,
#   0.0101,
#   0,
#   0.0385,
#   0.2782,
#   0.0503,
#   0.6922,
#   0.0535,
#   0.1421,
#   0.0111,
#   0.4206,
#   3.3397,
#   0.0548,
#   0.0281,
#   0.0111,
#   0.0084,
#   0.1604,
#   0.0368,
#   2.316,
#   0.2465,
#   0.0696,
#   0.0495,
#   0.0799,
#   0.1034,
#   0.075,
#   0.1786,
#   0.1561,
#   0.0381,
#   0.0276,
#   0.1578,
#   0.0221,
#   0.1619,
#   0,
#   0,
#   0,
#   0,
#   0,
#   10,
#   0,
#   0,
#   0],
#  'units_string': 'TFT12_Blitzcrank, TFT12_Hecarim, TFT12_KogMaw, TFT12_Nunu, TFT12_Shen, TFT12_Taric, TFT12_Veigar, TFT12_Ziggs',
#  'traits_string': 'TFT12_Bastion_2, TFT12_Honeymancy_2',
#  'name': [{'name': 'TFT12_Augment_NunuCarry',
#    'type': 'augment',
#    'score': 17.7272}],
#  'name_string': 'TFT12_Augment_NunuCarry',
#  'top_headliner': [],
#  'overall': {'count': 55500, 'avg': 4.4663},
#  'stars': ['TFT12_Nunu',
#   'TFT12_Blitzcrank',
#   'TFT12_Ziggs',
#   'TFT12_KogMaw',
#   'TFT12_Veigar',
#   'TFT12_Rumble',
#   'TFT12_Ahri',
#   'TFT12_Tristana',
#   'TFT12_Cassiopeia',
#   'TFT12_Wukong',
#   'TFT12_Syndra'],
#  'stars_4': [],
#  'builds': [{'cluster': '0',
#    'count': 16806,
#    'avg': 4.0075,
#    'unit': 'TFT12_Nunu',
#    'buildName': ['TFT_Item_ArchangelsStaff',
#     'TFT_Item_Bloodthirster',
#     'TFT_Item_WarmogsArmor'],
#    'build': [],
#    'num_items': 3,
#    'score': 0.5885,
#    'place_change': -0.459,
#    'unit_numitems_count': 49306},
#   {'cluster': '0',
#    'count': 1089,
#    'avg': 3.5877,
#    'unit': 'TFT12_Veigar',
#    'buildName': ['TFT_Item_BlueBuff',
#     'TFT_Item_Leviathan',
#     'TFT_Item_RabadonsDeathcap'],
#    'build': [],
#    'num_items': 3,
#    'score': 0.255,
#    'place_change': -0.879,
#    'unit_numitems_count': 18437},
#   {'cluster': '0',
#    'count': 2817,
#    'avg': 3.5793,
#    'unit': 'TFT12_KogMaw',
#    'buildName': ['TFT_Item_GuinsoosRageblade',
#     'TFT_Item_InfinityEdge',
#     'TFT_Item_LastWhisper'],
#    'build': [],
#    'num_items': 3,
#    'score': 0.2877,
#    'place_change': -0.887,
#    'unit_numitems_count': 17471},
#   {'cluster': '0',
#    'count': 155,
#    'avg': 4.129,
#    'unit': 'TFT12_Shen',
#    'buildName': ['TFT_Item_GargoyleStoneplate', 'TFT_Item_RedBuff'],
#    'build': [],
#    'num_items': 2,
#    'score': 0.0111,
#    'place_change': -0.337,
#    'unit_numitems_count': 10037}],
#  'build_items': {'TFT_Item_ArchangelsStaff': {'itemNames': 'TFT_Item_ArchangelsStaff',
#    'count': 42901,
#    'avg': 4.2799,
#    'pcnt': 0.77299},
#   'TFT_Item_WarmogsArmor': {'itemNames': 'TFT_Item_WarmogsArmor',
#    'count': 42736,
#    'avg': 4.167,
#    'pcnt': 0.77002},
#   'TFT_Item_Bloodthirster': {'itemNames': 'TFT_Item_Bloodthirster',
#    'count': 37211,
#    'avg': 4.1915,
#    'pcnt': 0.67047},
#   'TFT_Item_GuinsoosRageblade': {'itemNames': 'TFT_Item_GuinsoosRageblade',
#    'count': 26661,
#    'avg': 4.1383,
#    'pcnt': 0.48038},
#   'TFT_Item_GargoyleStoneplate': {'itemNames': 'TFT_Item_GargoyleStoneplate',
#    'count': 24629,
#    'avg': 4.2929,
#    'pcnt': 0.44377},
#   'TFT_Item_InfinityEdge': {'itemNames': 'TFT_Item_InfinityEdge',
#    'count': 16733,
#    'avg': 3.9976,
#    'pcnt': 0.3015},
#   'TFT_Item_LastWhisper': {'itemNames': 'TFT_Item_LastWhisper',
#    'count': 16186,
#    'avg': 3.9202,
#    'pcnt': 0.29164},
#   'TFT_Item_BlueBuff': {'itemNames': 'TFT_Item_BlueBuff',
#    'count': 14674,
#    'avg': 4.0365,
#    'pcnt': 0.2644},
#   'TFT_Item_Leviathan': {'itemNames': 'TFT_Item_Leviathan',
#    'count': 14621,
#    'avg': 3.9863,
#    'pcnt': 0.26344},
#   'TFT_Item_RedBuff': {'itemNames': 'TFT_Item_RedBuff',
#    'count': 13287,
#    'avg': 3.9396,
#    'pcnt': 0.23941},
#   'TFT_Item_RabadonsDeathcap': {'itemNames': 'TFT_Item_RabadonsDeathcap',
#    'count': 9792,
#    'avg': 3.8791,
#    'pcnt': 0.17643}},
#  'top_itemNames': [{'itemNames': 'TFT_Item_ArchangelsStaff',
#    'count': 42901,
#    'avg': 4.2799,
#    'pcnt': 0.77299},
#   {'itemNames': 'TFT_Item_WarmogsArmor',
#    'count': 42736,
#    'avg': 4.167,
#    'pcnt': 0.77002},
#   {'itemNames': 'TFT_Item_Bloodthirster',
#    'count': 37211,
#    'avg': 4.1915,
#    'pcnt': 0.67047}],
#  'top_items': [],
#  'trends': [{'day': '2024-08-17T00:00:00.000Z',
#    'count': 86,
#    'avg': 4.2442,
#    'pick': 0.0073535699016673796},
#   {'day': '2024-08-18T00:00:00.000Z',
#    'count': 72,
#    'avg': 4.5278,
#    'pick': 0.006093948370715192},
#   {'day': '2024-08-19T00:00:00.000Z',
#    'count': 125,
#    'avg': 4.008,
#    'pick': 0.006711769759450171},
#   {'day': '2024-08-20T00:00:00.000Z',
#    'count': 15131,
#    'avg': 4.5489,
#    'pick': 0.005610881944166329},
#   {'day': '2024-08-21T00:00:00.000Z',
#    'count': 18370,
#    'avg': 4.4554,
#    'pick': 0.005860452948889322},
#   {'day': '2024-08-22T00:00:00.000Z',
#    'count': 23231,
#    'avg': 4.4933,
#    'pick': 0.005949684178337372},
#   {'day': '2024-08-23T00:00:00.000Z',
#    'count': 30656,
#    'avg': 4.4447,
#    'pick': 0.00572773598604836}],
#  'top_augments': [{'aug': 'TFT12_Augment_NunuCarry',
#    'count': 49193,
#    'avg': 4.472,
#    'pcnt': 0.88636}],
#  'diff_pick': -0.009,
#  'diff_place': 0.043,
#  'difficulty': -0.052,
#  'levelling': 'lvl 6'}

# %%
q.idx('results.data').splay(0)
# Out:
# cluster_id
# tft_set
# cluster_details
# portals

# %%
"""
> clr            # Clear your current composition
> top            # Give me best compositions right now
> top zil        # Give me best compositions with Zilean.
> early zil      # Give me best early compositions with Zilean
> bi zil         # Give me best items for Zilean
> add zil twt ww # Stores Zilean, Twitch, and Warwick as part of your team.
> padd olaf      # If I add Olaf, what is the best composition?
> q Zilean       # Give me aliases for Zilean (zil, zi, Zilean)
"""
# Out:
# '\n> clr            # Clear your current composition\n> top            # Give me best compositions right now\n> top zil        # Give me best compositions with Zilean.\n> early zil      # Give me best early compositions with Zilean\n> bi zil         # Give me best items for Zilean\n> add zil twt ww # Stores Zilean, Twitch, and Warwick as part of your team.\n> padd olaf      # If I add Olaf, what is the best composition?\n> q Zilean       # Give me aliases for Zilean (zil, zi, Zilean)\n'

# %%
q2.idx('items').filter(ql.idx('composition').len().eq(2)).idx('0').sub({
    'en_name': ql.idx('en_name'),
    'effects': ql.idx('effects.AP')
}).eval()
# a = {
#     "a": [
#         {
#             "name": "Bob",
#             "eyes": "blue"
#         },
#         {
#             "name": "Joe",
#             "eyes": "brown"
#         }
#     ]
# }

# ql.query(a).idx("a").filter(ql.idx('eyes').eq('blue')).idx('name').eval()
# Out:
# {'en_name': "Rabadon's Deathcap", 'effects': 50}

# %%
# champions.filter(ql.idx('traits').contains('Frost')).map(ql.idx('en_name')).eval()
champions.map(ql.idx('apiName')).vals().eval()
# Out:
# ['TFT12_Zilean',
#  'TFT12_Twitch',
#  'TFT12_Warwick',
#  'TFT12_Hwei',
#  'TFT12_Diana',
#  'TFT12_Jax',
#  'TFT12_Vex',
#  'TFT12_Smolder',
#  'TFT12_Karma',
#  'TFT12_Camille',
#  'TFT12_Blitzcrank',
#  'TFT12_Elise',
#  'TFT12_Jayce',
#  'TFT12_Tristana',
#  'TFT12_Ashe',
#  'TFT12_Zoe',
#  'TFT12_Nilah',
#  'TFT12_Kassadin',
#  'TFT12_KogMaw',
#  'TFT12_Cassiopeia',
#  'TFT12_Syndra',
#  'TFT12_Nunu',
#  'TFT12_Katarina',
#  'TFT12_Hecarim',
#  'TFT12_Neeko',
#  'TFT12_Ezreal',
#  'TFT12_Jinx',
#  'TFT12_Veigar',
#  'TFT12_Bard',
#  'TFT12_Lillia',
#  'TFT12_Mordekaiser',
#  'TFT12_Fiora',
#  'TFT12_Gwen',
#  'TFT12_Rakan',
#  'TFT12_TahmKench',
#  'TFT12_Kalista',
#  'TFT12_Ryze',
#  'TFT12_Nami',
#  'TFT12_Briar',
#  'TFT12_Morgana',
#  'TFT12_Xerath',
#  'TFT12_Milio',
#  'TFT12_Norra',
#  'TFT12_Nomsy',
#  'TFT12_Varus',
#  'TFT12_Nasus',
#  'TFT12_Akali',
#  'TFT12_Taric',
#  'TFT12_Galio',
#  'TFT12_Shen',
#  'TFT12_Shyvana',
#  'TFT12_Poppy',
#  'TFT12_Rumble',
#  'TFT12_Ziggs',
#  'TFT12_Swain',
#  'TFT12_Ahri',
#  'TFT12_Soraka',
#  'TFT12_Seraphine',
#  'TFT12_Olaf',
#  'TFT12_Wukong']

# %%
def avg_place(places: Any) -> Any:
    tot = sum(places)
    return sum((i+1) * x / tot for i, x in enumerate(places))

q3.idx('TFT12_Zilean.items').filter(ql.idx('itemName').in_set(buildable_item_name_map)).map(ql.sub({
    'name': ql.idx('itemName').replace(buildable_item_name_map),
    "avg_place": ql.idx('places').unary(avg_place),
    "games": ql.idx('places').unary(sum)
})).values().sort_by(ql.idx('games'), True).filter(ql.idx('games').gt(100)).top(10).eval()
# Out:
# [{'name': 'Spear of Shojin', 'avg_place': 4.299324935625305, 'games': 14369},
#  {'name': "Nashor's Tooth", 'avg_place': 4.163744624545154, 'games': 9069},
#  {'name': 'Statikk Shiv', 'avg_place': 3.8499610288386594, 'games': 7698},
#  {'name': 'Jeweled Gauntlet', 'avg_place': 4.267036011080332, 'games': 7220},
#  {'name': "Archangel's Staff", 'avg_place': 4.2336858006042295, 'games': 6620},
#  {'name': 'Adaptive Helm', 'avg_place': 3.9694484643833414, 'games': 6219},
#  {'name': "Rabadon's Deathcap", 'avg_place': 4.151035527866644, 'games': 5939},
#  {'name': 'Giant Slayer', 'avg_place': 4.098597194388778, 'games': 4990},
#  {'name': 'Guardbreaker', 'avg_place': 4.05513468013468, 'games': 4752},
#  {'name': 'Morellonomicon', 'avg_place': 4.221079103795153, 'games': 4374}]

# %%
q3.idx('TFT12_Zilean.builds').map(ql.sub({
    'items': ql.idx('buildNames').split('|'),
    'avg_place': ql.idx('places').unary(avg_place)
})).filter(ql.idx('items')).eval()

# q3.idx('TFT12_Zilean.builds').map(ql.idx('buildNames').split('|')).eval()
# Out:
# {0: {'items': ['TFT12_Item_ArcanaEmblemItem'], 'avg_place': 4.339506172839506},
#  1: {'items': ['TFT12_Item_ArcanaEmblemItem', 'TFT12_Item_IncantorEmblemItem'],
#   'avg_place': 3.9166666666666665},
#  2: {'items': ['TFT12_Item_ArcanaEmblemItem',
#    'TFT12_Item_MultistrikerEmblemItem'],
#   'avg_place': 4.769230769230769},
#  3: {'items': ['TFT12_Item_ArcanaEmblemItem', 'TFT12_Item_ScholarEmblemItem'],
#   'avg_place': 4.5},
#  4: {'items': ['TFT12_Item_ArcanaEmblemItem',
#    'TFT12_Item_SugarcraftEmblemItem'],
#   'avg_place': 4.285714285714286},
#  5: {'items': ['TFT12_Item_ArcanaEmblemItem', 'TFT_Item_Leviathan'],
#   'avg_place': 3.6666666666666665},
#  6: {'items': ['TFT12_Item_ArcanaEmblemItem', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.916666666666667},
#  7: {'items': ['TFT12_Item_ArcanaEmblemItem', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.6},
#  8: {'items': ['TFT12_Item_ArcanaEmblemItem', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.8},
#  9: {'items': ['TFT12_Item_BastionEmblemItem'],
#   'avg_place': 4.131578947368421},
#  10: {'items': ['TFT12_Item_BlasterEmblemItem'],
#   'avg_place': 4.818037974683544},
#  11: {'items': ['TFT12_Item_BlasterEmblemItem', 'TFT12_Item_PyroEmblemItem'],
#   'avg_place': 3.6875},
#  12: {'items': ['TFT12_Item_BlasterEmblemItem',
#    'TFT12_Item_ScholarEmblemItem'],
#   'avg_place': 4.470588235294118},
#  13: {'items': ['TFT12_Item_BlasterEmblemItem',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.9375},
#  14: {'items': ['TFT12_Item_BlasterEmblemItem',
#    'TFT_Item_Leviathan',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 5.181818181818182},
#  15: {'items': ['TFT12_Item_BlasterEmblemItem', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.888888888888889},
#  16: {'items': ['TFT12_Item_BlasterEmblemItem', 'TFT_Item_StatikkShiv'],
#   'avg_place': 4.696969696969697},
#  17: {'items': ['TFT12_Item_EldritchEmblemItem'],
#   'avg_place': 4.043478260869565},
#  18: {'items': ['TFT12_Item_FaerieEmblemItem'],
#   'avg_place': 4.392059553349876},
#  19: {'items': ['TFT12_Item_FaerieEmblemItem',
#    'TFT12_Item_Faerie_QueensCrown'],
#   'avg_place': 3.6455696202531644},
#  20: {'items': ['TFT12_Item_FaerieEmblemItem', 'TFT_Item_AdaptiveHelm'],
#   'avg_place': 3.1818181818181817},
#  21: {'items': ['TFT12_Item_FaerieEmblemItem', 'TFT_Item_ArchangelsStaff'],
#   'avg_place': 4.157894736842105},
#  22: {'items': ['TFT12_Item_FaerieEmblemItem', 'TFT_Item_JeweledGauntlet'],
#   'avg_place': 3.1904761904761902},
#  23: {'items': ['TFT12_Item_FaerieEmblemItem', 'TFT_Item_Leviathan'],
#   'avg_place': 3.4857142857142858},
#  24: {'items': ['TFT12_Item_FaerieEmblemItem', 'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 3.9473684210526314},
#  25: {'items': ['TFT12_Item_FaerieEmblemItem', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.5238095238095237},
#  26: {'items': ['TFT12_Item_FaerieEmblemItem', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.0},
#  27: {'items': ['TFT12_Item_Faerie_QueensCrown'],
#   'avg_place': 3.9090909090909087},
#  28: {'items': ['TFT12_Item_HoneymancyEmblemItem'],
#   'avg_place': 3.9078947368421053},
#  29: {'items': ['TFT12_Item_HunterEmblemItem'],
#   'avg_place': 4.784604519774011},
#  30: {'items': ['TFT12_Item_HunterEmblemItem', 'TFT12_Item_ScholarEmblemItem'],
#   'avg_place': 3.85},
#  31: {'items': ['TFT12_Item_HunterEmblemItem',
#    'TFT12_Item_SugarcraftEmblemItem'],
#   'avg_place': 4.818181818181818},
#  32: {'items': ['TFT12_Item_HunterEmblemItem',
#    'TFT12_Item_WitchcraftEmblemItem'],
#   'avg_place': 4.0},
#  33: {'items': ['TFT12_Item_HunterEmblemItem', 'TFT_Item_AdaptiveHelm'],
#   'avg_place': 4.269230769230769},
#  34: {'items': ['TFT12_Item_HunterEmblemItem', 'TFT_Item_ArchangelsStaff'],
#   'avg_place': 4.045454545454545},
#  35: {'items': ['TFT12_Item_HunterEmblemItem', 'TFT_Item_BlueBuff'],
#   'avg_place': 5.208333333333333},
#  36: {'items': ['TFT12_Item_HunterEmblemItem', 'TFT_Item_ForceOfNature'],
#   'avg_place': 4.473684210526315},
#  37: {'items': ['TFT12_Item_HunterEmblemItem', 'TFT_Item_GuinsoosRageblade'],
#   'avg_place': 5.333333333333333},
#  38: {'items': ['TFT12_Item_HunterEmblemItem', 'TFT_Item_JeweledGauntlet'],
#   'avg_place': 4.173913043478261},
#  39: {'items': ['TFT12_Item_HunterEmblemItem', 'TFT_Item_Leviathan'],
#   'avg_place': 5.319999999999999},
#  40: {'items': ['TFT12_Item_HunterEmblemItem', 'TFT_Item_Morellonomicon'],
#   'avg_place': 4.3},
#  41: {'items': ['TFT12_Item_HunterEmblemItem', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 5.0},
#  42: {'items': ['TFT12_Item_HunterEmblemItem', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.8333333333333335},
#  43: {'items': ['TFT12_Item_HunterEmblemItem', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 5.0344827586206895},
#  44: {'items': ['TFT12_Item_HunterEmblemItem', 'TFT_Item_StatikkShiv'],
#   'avg_place': 4.625},
#  45: {'items': ['TFT12_Item_HunterEmblemItem', 'TFT_Item_ZekesHerald'],
#   'avg_place': 3.9166666666666665},
#  46: {'items': ['TFT12_Item_IncantorEmblemItem'],
#   'avg_place': 4.814102564102564},
#  47: {'items': ['TFT12_Item_IncantorEmblemItem',
#    'TFT12_Item_MultistrikerEmblemItem'],
#   'avg_place': 4.769230769230769},
#  48: {'items': ['TFT12_Item_IncantorEmblemItem',
#    'TFT12_Item_ScholarEmblemItem'],
#   'avg_place': 5.285714285714286},
#  49: {'items': ['TFT12_Item_IncantorEmblemItem',
#    'TFT12_Item_SugarcraftEmblemItem'],
#   'avg_place': 4.428571428571429},
#  50: {'items': ['TFT12_Item_IncantorEmblemItem',
#    'TFT12_Item_WitchcraftEmblemItem'],
#   'avg_place': 3.4375},
#  51: {'items': ['TFT12_Item_IncantorEmblemItem', 'TFT_Item_AdaptiveHelm'],
#   'avg_place': 3.6363636363636362},
#  52: {'items': ['TFT12_Item_IncantorEmblemItem', 'TFT_Item_Leviathan'],
#   'avg_place': 4.0},
#  53: {'items': ['TFT12_Item_IncantorEmblemItem', 'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 4.076923076923077},
#  54: {'items': ['TFT12_Item_IncantorEmblemItem', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.458333333333333},
#  55: {'items': ['TFT12_Item_IncantorEmblemItem', 'TFT_Item_StatikkShiv'],
#   'avg_place': 4.4},
#  56: {'items': ['TFT12_Item_MageEmblemItem'], 'avg_place': 4.4279329608938545},
#  57: {'items': ['TFT12_Item_MageEmblemItem',
#    'TFT12_Item_MultistrikerEmblemItem'],
#   'avg_place': 4.333333333333333},
#  58: {'items': ['TFT12_Item_MageEmblemItem', 'TFT12_Item_PortalEmblemItem'],
#   'avg_place': 4.0},
#  59: {'items': ['TFT12_Item_MageEmblemItem', 'TFT12_Item_ScholarEmblemItem'],
#   'avg_place': 4.875},
#  60: {'items': ['TFT12_Item_MageEmblemItem',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.363636363636363},
#  61: {'items': ['TFT12_Item_MageEmblemItem', 'TFT_Item_Leviathan'],
#   'avg_place': 3.7368421052631575},
#  62: {'items': ['TFT12_Item_MageEmblemItem', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 4.636363636363637},
#  63: {'items': ['TFT12_Item_MageEmblemItem', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.904761904761904},
#  64: {'items': ['TFT12_Item_MageEmblemItem', 'TFT_Item_StatikkShiv'],
#   'avg_place': 4.777777777777778},
#  65: {'items': ['TFT12_Item_MultistrikerEmblemItem'],
#   'avg_place': 4.86734693877551},
#  66: {'items': ['TFT12_Item_MultistrikerEmblemItem',
#    'TFT12_Item_WitchcraftEmblemItem'],
#   'avg_place': 4.545454545454545},
#  67: {'items': ['TFT12_Item_MultistrikerEmblemItem',
#    'TFT_Item_ArchangelsStaff'],
#   'avg_place': 4.909090909090909},
#  68: {'items': ['TFT12_Item_MultistrikerEmblemItem',
#    'TFT_Item_JeweledGauntlet'],
#   'avg_place': 3.5454545454545454},
#  69: {'items': ['TFT12_Item_MultistrikerEmblemItem', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.5},
#  70: {'items': ['TFT12_Item_MultistrikerEmblemItem', 'TFT_Item_StatikkShiv'],
#   'avg_place': 5.0},
#  71: {'items': ['TFT12_Item_PortalEmblemItem'],
#   'avg_place': 3.853061224489796},
#  72: {'items': ['TFT12_Item_PortalEmblemItem', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.090909090909091},
#  73: {'items': ['TFT12_Item_PortalEmblemItem', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.466666666666667},
#  74: {'items': ['TFT12_Item_PyroEmblemItem'], 'avg_place': 3.76793893129771},
#  75: {'items': ['TFT12_Item_PyroEmblemItem', 'TFT_Item_GuinsoosRageblade'],
#   'avg_place': 4.75},
#  76: {'items': ['TFT12_Item_PyroEmblemItem', 'TFT_Item_Morellonomicon'],
#   'avg_place': 4.086956521739131},
#  77: {'items': ['TFT12_Item_PyroEmblemItem', 'TFT_Item_RapidFireCannon'],
#   'avg_place': 3.0625},
#  78: {'items': ['TFT12_Item_PyroEmblemItem', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.9333333333333336},
#  79: {'items': ['TFT12_Item_PyroEmblemItem', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.4},
#  80: {'items': ['TFT12_Item_ScholarEmblemItem'],
#   'avg_place': 4.900265957446808},
#  81: {'items': ['TFT12_Item_ScholarEmblemItem',
#    'TFT12_Item_SugarcraftEmblemItem'],
#   'avg_place': 4.064516129032258},
#  82: {'items': ['TFT12_Item_ScholarEmblemItem',
#    'TFT12_Item_WitchcraftEmblemItem'],
#   'avg_place': 3.3181818181818183},
#  83: {'items': ['TFT12_Item_ScholarEmblemItem', 'TFT_Item_AdaptiveHelm'],
#   'avg_place': 4.962962962962963},
#  84: {'items': ['TFT12_Item_ScholarEmblemItem', 'TFT_Item_ArchangelsStaff'],
#   'avg_place': 4.357142857142857},
#  85: {'items': ['TFT12_Item_ScholarEmblemItem', 'TFT_Item_JeweledGauntlet'],
#   'avg_place': 4.523809523809524},
#  86: {'items': ['TFT12_Item_ScholarEmblemItem',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.583333333333333},
#  87: {'items': ['TFT12_Item_ScholarEmblemItem', 'TFT_Item_Leviathan'],
#   'avg_place': 4.6875},
#  88: {'items': ['TFT12_Item_ScholarEmblemItem', 'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 5.045454545454546},
#  89: {'items': ['TFT12_Item_ScholarEmblemItem', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 4.0},
#  90: {'items': ['TFT12_Item_ScholarEmblemItem', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.724137931034483},
#  91: {'items': ['TFT12_Item_ScholarEmblemItem', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 5.1063829787234045},
#  92: {'items': ['TFT12_Item_ScholarEmblemItem',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 4.2727272727272725},
#  93: {'items': ['TFT12_Item_ScholarEmblemItem', 'TFT_Item_StatikkShiv'],
#   'avg_place': 5.090909090909091},
#  94: {'items': ['TFT12_Item_ShapeshifterEmblemItem'],
#   'avg_place': 4.72463768115942},
#  95: {'items': ['TFT12_Item_SugarcraftEmblemItem'],
#   'avg_place': 4.581005586592179},
#  96: {'items': ['TFT12_Item_SugarcraftEmblemItem', 'TFT_Item_AdaptiveHelm'],
#   'avg_place': 3.3846153846153846},
#  97: {'items': ['TFT12_Item_SugarcraftEmblemItem', 'TFT_Item_ArchangelsStaff'],
#   'avg_place': 3.6190476190476186},
#  98: {'items': ['TFT12_Item_SugarcraftEmblemItem', 'TFT_Item_ForceOfNature'],
#   'avg_place': 4.071428571428571},
#  99: {'items': ['TFT12_Item_SugarcraftEmblemItem', 'TFT_Item_JeweledGauntlet'],
#   'avg_place': 4.5},
#  100: {'items': ['TFT12_Item_SugarcraftEmblemItem', 'TFT_Item_Leviathan'],
#   'avg_place': 3.64},
#  101: {'items': ['TFT12_Item_SugarcraftEmblemItem',
#    'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 4.25},
#  102: {'items': ['TFT12_Item_SugarcraftEmblemItem', 'TFT_Item_Morellonomicon'],
#   'avg_place': 4.333333333333333},
#  103: {'items': ['TFT12_Item_SugarcraftEmblemItem', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 3.1333333333333333},
#  104: {'items': ['TFT12_Item_SugarcraftEmblemItem',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.833333333333333},
#  105: {'items': ['TFT12_Item_SugarcraftEmblemItem', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.108108108108108},
#  106: {'items': ['TFT12_Item_SugarcraftEmblemItem', 'TFT_Item_StatikkShiv'],
#   'avg_place': 4.05},
#  107: {'items': ['TFT12_Item_VanguardEmblemItem'],
#   'avg_place': 4.971887550200803},
#  108: {'items': ['TFT12_Item_VanguardEmblemItem', 'TFT_Item_StatikkShiv'],
#   'avg_place': 4.761904761904762},
#  109: {'items': ['TFT12_Item_WarriorEmblemItem'],
#   'avg_place': 4.860294117647059},
#  110: {'items': ['TFT12_Item_WitchcraftEmblemItem'],
#   'avg_place': 3.3582089552238807},
#  111: {'items': ['TFT12_Item_WitchcraftEmblemItem', 'TFT_Item_AdaptiveHelm'],
#   'avg_place': 3.0},
#  112: {'items': ['TFT12_Item_WitchcraftEmblemItem',
#    'TFT_Item_ArchangelsStaff'],
#   'avg_place': 4.176470588235294},
#  113: {'items': ['TFT12_Item_WitchcraftEmblemItem', 'TFT_Item_BlueBuff'],
#   'avg_place': 3.0},
#  114: {'items': ['TFT12_Item_WitchcraftEmblemItem',
#    'TFT_Item_GuinsoosRageblade'],
#   'avg_place': 3.8666666666666667},
#  115: {'items': ['TFT12_Item_WitchcraftEmblemItem',
#    'TFT_Item_JeweledGauntlet'],
#   'avg_place': 4.3125},
#  116: {'items': ['TFT12_Item_WitchcraftEmblemItem', 'TFT_Item_Leviathan'],
#   'avg_place': 3.3684210526315788},
#  117: {'items': ['TFT12_Item_WitchcraftEmblemItem', 'TFT_Item_Morellonomicon'],
#   'avg_place': 3.5833333333333335},
#  118: {'items': ['TFT12_Item_WitchcraftEmblemItem', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 2.727272727272727},
#  119: {'items': ['TFT12_Item_WitchcraftEmblemItem',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.3333333333333335},
#  120: {'items': ['TFT12_Item_WitchcraftEmblemItem', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.2954545454545454},
#  121: {'items': ['TFT12_Item_WitchcraftEmblemItem', 'TFT_Item_StatikkShiv'],
#   'avg_place': 2.7966101694915255},
#  122: {'items': ['TFT4_Item_OrnnMuramana'], 'avg_place': 4.184873949579832},
#  123: {'items': ['TFT4_Item_OrnnMuramana',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.285714285714286},
#  124: {'items': ['TFT4_Item_OrnnObsidianCleaver'],
#   'avg_place': 4.438356164383562},
#  125: {'items': ['TFT4_Item_OrnnRanduinsSanctum'],
#   'avg_place': 4.431496062992126},
#  126: {'items': ['TFT4_Item_OrnnRanduinsSanctum', 'TFT_Item_AdaptiveHelm'],
#   'avg_place': 3.5384615384615388},
#  127: {'items': ['TFT4_Item_OrnnZhonyasParadox'],
#   'avg_place': 3.4545454545454546},
#  128: {'items': ['TFT5_Item_AdaptiveHelmRadiant'],
#   'avg_place': 1.8181818181818181},
#  129: {'items': ['TFT5_Item_ArchangelsStaffRadiant'],
#   'avg_place': 1.5454545454545454},
#  130: {'items': ['TFT5_Item_GiantSlayerRadiant'],
#   'avg_place': 1.7142857142857142},
#  131: {'items': ['TFT5_Item_LeviathanRadiant'], 'avg_place': 1.375},
#  132: {'items': ['TFT5_Item_LeviathanRadiant',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 5.461538461538462},
#  133: {'items': ['TFT5_Item_SpearOfShojinRadiant'],
#   'avg_place': 1.9545454545454546},
#  134: {'items': ['TFT5_Item_SpearOfShojinRadiant',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_Leviathan'],
#   'avg_place': 4.666666666666667},
#  135: {'items': ['TFT5_Item_StatikkShivRadiant'], 'avg_place': 4.125},
#  136: {'items': ['TFT5_Item_ThiefsGlovesRadiant'],
#   'avg_place': 4.685714285714286},
#  137: {'items': ['TFT5_Item_ZzRotPortalRadiant'],
#   'avg_place': 3.916666666666667},
#  138: {'items': ['TFT7_Item_ShimmerscaleGamblersBlade'],
#   'avg_place': 4.3731884057971016},
#  139: {'items': ['TFT7_Item_ShimmerscaleGamblersBlade',
#    'TFT_Item_GuinsoosRageblade'],
#   'avg_place': 4.8125},
#  140: {'items': ['TFT7_Item_ShimmerscaleGamblersBlade',
#    'TFT_Item_Morellonomicon'],
#   'avg_place': 5.142857142857142},
#  141: {'items': ['TFT7_Item_ShimmerscaleGamblersBlade',
#    'TFT_Item_RapidFireCannon'],
#   'avg_place': 4.333333333333333},
#  142: {'items': ['TFT7_Item_ShimmerscaleGamblersBlade',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.739130434782608},
#  143: {'items': ['TFT7_Item_ShimmerscaleGamblersBlade',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.8666666666666667},
#  144: {'items': ['TFT7_Item_ShimmerscaleHeartOfGold'],
#   'avg_place': 4.332391713747646},
#  145: {'items': ['TFT7_Item_ShimmerscaleHeartOfGold',
#    'TFT_Item_ArchangelsStaff'],
#   'avg_place': 3.8},
#  146: {'items': ['TFT7_Item_ShimmerscaleHeartOfGold', 'TFT_Item_EternalFlame'],
#   'avg_place': 4.421052631578947},
#  147: {'items': ['TFT7_Item_ShimmerscaleHeartOfGold',
#    'TFT_Item_JeweledGauntlet'],
#   'avg_place': 4.05},
#  148: {'items': ['TFT7_Item_ShimmerscaleHeartOfGold', 'TFT_Item_Leviathan'],
#   'avg_place': 3.6666666666666665},
#  149: {'items': ['TFT7_Item_ShimmerscaleHeartOfGold', 'TFT_Item_Moonstone'],
#   'avg_place': 4.484848484848484},
#  150: {'items': ['TFT7_Item_ShimmerscaleHeartOfGold',
#    'TFT_Item_Morellonomicon'],
#   'avg_place': 3.7058823529411766},
#  151: {'items': ['TFT7_Item_ShimmerscaleHeartOfGold',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.0833333333333335},
#  152: {'items': ['TFT7_Item_ShimmerscaleHeartOfGold',
#    'TFT_Item_RapidFireCannon'],
#   'avg_place': 4.230769230769231},
#  153: {'items': ['TFT7_Item_ShimmerscaleHeartOfGold',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 5.3125},
#  154: {'items': ['TFT7_Item_ShimmerscaleHeartOfGold', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.9655172413793105},
#  155: {'items': ['TFT9_Item_OrnnDeathfireGrasp'],
#   'avg_place': 4.529411764705882},
#  156: {'items': ['TFT9_Item_OrnnHorizonFocus'],
#   'avg_place': 4.431818181818182},
#  157: {'items': ['TFT9_Item_OrnnHorizonFocus', 'TFT9_Item_OrnnHorizonFocus'],
#   'avg_place': 5.375},
#  158: {'items': ['TFT9_Item_OrnnHorizonFocus',
#    'TFT9_Item_OrnnHorizonFocus',
#    'TFT9_Item_OrnnHorizonFocus'],
#   'avg_place': 6.545454545454545},
#  159: {'items': ['TFT9_Item_OrnnHorizonFocus',
#    'TFT_Item_Artifact_Fishbones',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.266666666666667},
#  160: {'items': ['TFT9_Item_OrnnTrickstersGlass'], 'avg_place': 4.94},
#  161: {'items': ['TFT_Item_AdaptiveHelm'], 'avg_place': 4.196360558611934},
#  162: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_AdaptiveHelm'],
#   'avg_place': 3.8977272727272725},
#  163: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_AdaptiveHelm',
#    'TFT_Item_ArchangelsStaff'],
#   'avg_place': 4.2727272727272725},
#  164: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_AdaptiveHelm',
#    'TFT_Item_JeweledGauntlet'],
#   'avg_place': 4.5},
#  165: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_AdaptiveHelm',
#    'TFT_Item_Leviathan'],
#   'avg_place': 3.357142857142857},
#  166: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_AdaptiveHelm',
#    'TFT_Item_PowerGauntlet'],
#   'avg_place': 4.2},
#  167: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_AdaptiveHelm',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.75},
#  168: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_AdaptiveHelm',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.3333333333333335},
#  169: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_ArchangelsStaff'],
#   'avg_place': 3.5806451612903225},
#  170: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_ArchangelsStaff',
#    'TFT_Item_JeweledGauntlet'],
#   'avg_place': 3.611111111111111},
#  171: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_ArchangelsStaff',
#    'TFT_Item_Leviathan'],
#   'avg_place': 4.576923076923077},
#  172: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_ArchangelsStaff',
#    'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 3.764705882352941},
#  173: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_ArchangelsStaff',
#    'TFT_Item_PowerGauntlet'],
#   'avg_place': 3.3125},
#  174: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_ArchangelsStaff',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.375},
#  175: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_ArchangelsStaff',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.638888888888889},
#  176: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_BlueBuff'],
#   'avg_place': 3.5806451612903225},
#  177: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_EternalFlame'],
#   'avg_place': 4.416666666666667},
#  178: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_ForceOfNature'],
#   'avg_place': 2.8333333333333335},
#  179: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_GuinsoosRageblade'],
#   'avg_place': 3.7142857142857144},
#  180: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_GuinsoosRageblade',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.411764705882353},
#  181: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_GuinsoosRageblade',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.571428571428571},
#  182: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_JeweledGauntlet'],
#   'avg_place': 4.176100628930818},
#  183: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_Leviathan'],
#   'avg_place': 4.0},
#  184: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 3.85},
#  185: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_Morellonomicon'],
#   'avg_place': 3.1666666666666665},
#  186: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_PowerGauntlet'],
#   'avg_place': 4.1875},
#  187: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.393939393939394},
#  188: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.153846153846153},
#  189: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 4.0476190476190474},
#  190: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_Leviathan'],
#   'avg_place': 3.769230769230769},
#  191: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_Leviathan',
#    'TFT_Item_Leviathan'],
#   'avg_place': 3.454545454545454},
#  192: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_Leviathan',
#    'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 3.75},
#  193: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_Leviathan',
#    'TFT_Item_Morellonomicon'],
#   'avg_place': 3.3157894736842106},
#  194: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_Leviathan',
#    'TFT_Item_PowerGauntlet'],
#   'avg_place': 4.25},
#  195: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_Leviathan',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.451612903225806},
#  196: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_Leviathan',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.847457627118644},
#  197: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_Leviathan',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.857142857142857},
#  198: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 3.8686131386861313},
#  199: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_MadredsBloodrazor',
#    'TFT_Item_PowerGauntlet'],
#   'avg_place': 3.9375},
#  200: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_MadredsBloodrazor',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.611111111111111},
#  201: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_MadredsBloodrazor',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.85},
#  202: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_Moonstone'],
#   'avg_place': 4.136363636363636},
#  203: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_Morellonomicon'],
#   'avg_place': 4.36231884057971},
#  204: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_Morellonomicon',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.1923076923076925},
#  205: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_Morellonomicon',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 4.368421052631579},
#  206: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 3.8175182481751824},
#  207: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_PowerGauntlet',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.6818181818181817},
#  208: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_PowerGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.4782608695652173},
#  209: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.7894736842105265},
#  210: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_RabadonsDeathcap',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.241379310344827},
#  211: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_RabadonsDeathcap',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 4.0},
#  212: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_RapidFireCannon'],
#   'avg_place': 4.032258064516129},
#  213: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_RapidFireCannon',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 2.875},
#  214: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.892682926829268},
#  215: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.7777777777777777},
#  216: {'items': ['TFT_Item_AdaptiveHelm',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.76},
#  217: {'items': ['TFT_Item_AdaptiveHelm', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.9405940594059405},
#  218: {'items': ['TFT_Item_AegisOfTheLegion'], 'avg_place': 4.0},
#  219: {'items': ['TFT_Item_ArchangelsStaff'], 'avg_place': 4.405165767154973},
#  220: {'items': ['TFT_Item_ArchangelsStaff', 'TFT_Item_ArchangelsStaff'],
#   'avg_place': 4.485714285714286},
#  221: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_ArchangelsStaff',
#    'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 4.75},
#  222: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_ArchangelsStaff',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.0},
#  223: {'items': ['TFT_Item_ArchangelsStaff', 'TFT_Item_BlueBuff'],
#   'avg_place': 4.2439024390243905},
#  224: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_BlueBuff',
#    'TFT_Item_Leviathan'],
#   'avg_place': 4.666666666666667},
#  225: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_BlueBuff',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.3636363636363633},
#  226: {'items': ['TFT_Item_ArchangelsStaff', 'TFT_Item_ForceOfNature'],
#   'avg_place': 3.4210526315789473},
#  227: {'items': ['TFT_Item_ArchangelsStaff', 'TFT_Item_GuinsoosRageblade'],
#   'avg_place': 4.3076923076923075},
#  228: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_GuinsoosRageblade',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.75},
#  229: {'items': ['TFT_Item_ArchangelsStaff', 'TFT_Item_JeweledGauntlet'],
#   'avg_place': 4.339743589743589},
#  230: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_Leviathan'],
#   'avg_place': 3.966666666666667},
#  231: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 4.25},
#  232: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_PowerGauntlet'],
#   'avg_place': 5.076923076923077},
#  233: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.157894736842105},
#  234: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.909836065573771},
#  235: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.2857142857142856},
#  236: {'items': ['TFT_Item_ArchangelsStaff', 'TFT_Item_Leviathan'],
#   'avg_place': 4.063583815028902},
#  237: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_Leviathan',
#    'TFT_Item_Leviathan'],
#   'avg_place': 3.4285714285714284},
#  238: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_Leviathan',
#    'TFT_Item_PowerGauntlet'],
#   'avg_place': 4.470588235294118},
#  239: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_Leviathan',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.730769230769231},
#  240: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_Leviathan',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.427244582043343},
#  241: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_Leviathan',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.210526315789474},
#  242: {'items': ['TFT_Item_ArchangelsStaff', 'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 4.0071942446043165},
#  243: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_MadredsBloodrazor',
#    'TFT_Item_PowerGauntlet'],
#   'avg_place': 3.2666666666666666},
#  244: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_MadredsBloodrazor',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.363636363636363},
#  245: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_MadredsBloodrazor',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.96875},
#  246: {'items': ['TFT_Item_ArchangelsStaff', 'TFT_Item_Moonstone'],
#   'avg_place': 4.75},
#  247: {'items': ['TFT_Item_ArchangelsStaff', 'TFT_Item_Morellonomicon'],
#   'avg_place': 4.111111111111111},
#  248: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_Morellonomicon',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.333333333333333},
#  249: {'items': ['TFT_Item_ArchangelsStaff', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 3.838709677419355},
#  250: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_PowerGauntlet',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.9166666666666665},
#  251: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_PowerGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.55},
#  252: {'items': ['TFT_Item_ArchangelsStaff', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.402777777777778},
#  253: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_RabadonsDeathcap',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.8947368421052633},
#  254: {'items': ['TFT_Item_ArchangelsStaff', 'TFT_Item_RapidFireCannon'],
#   'avg_place': 4.121212121212121},
#  255: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_RapidFireCannon',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.0},
#  256: {'items': ['TFT_Item_ArchangelsStaff', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.228699551569507},
#  257: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.588235294117647},
#  258: {'items': ['TFT_Item_ArchangelsStaff',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.8235294117647056},
#  259: {'items': ['TFT_Item_ArchangelsStaff', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.7746478873239435},
#  260: {'items': ['TFT_Item_Artifact_BlightingJewel'],
#   'avg_place': 4.533333333333333},
#  261: {'items': ['TFT_Item_Artifact_Fishbones'],
#   'avg_place': 5.133333333333333},
#  262: {'items': ['TFT_Item_Artifact_HorizonFocus'],
#   'avg_place': 4.380281690140845},
#  263: {'items': ['TFT_Item_Artifact_HorizonFocus',
#    'TFT_Item_GuinsoosRageblade',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 5.066666666666666},
#  264: {'items': ['TFT_Item_Artifact_HorizonFocus',
#    'TFT_Item_Leviathan',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.648648648648649},
#  265: {'items': ['TFT_Item_Artifact_HorizonFocus', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.238095238095238},
#  266: {'items': ['TFT_Item_Artifact_LichBane'], 'avg_place': 4.75},
#  267: {'items': ['TFT_Item_Artifact_LightshieldCrest'],
#   'avg_place': 4.660377358490566},
#  268: {'items': ['TFT_Item_Artifact_LudensTempest'],
#   'avg_place': 5.102564102564103},
#  269: {'items': ['TFT_Item_Artifact_LudensTempest',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 5.785714285714286},
#  270: {'items': ['TFT_Item_Artifact_RapidFirecannon'],
#   'avg_place': 4.615384615384616},
#  271: {'items': ['TFT_Item_Artifact_SilvermereDawn'],
#   'avg_place': 4.586206896551724},
#  272: {'items': ['TFT_Item_Artifact_SpectralCutlass'], 'avg_place': 5.5},
#  273: {'items': ['TFT_Item_Artifact_SuspiciousTrenchCoat'],
#   'avg_place': 3.7403314917127073},
#  274: {'items': ['TFT_Item_Artifact_TalismanOfAscension'],
#   'avg_place': 5.2727272727272725},
#  275: {'items': ['TFT_Item_Artifact_WitsEnd'], 'avg_place': 4.571428571428571},
#  276: {'items': ['TFT_Item_BansheesVeil'], 'avg_place': 4.699074074074074},
#  277: {'items': ['TFT_Item_Bloodthirster'], 'avg_place': 4.351351351351352},
#  278: {'items': ['TFT_Item_BlueBuff'], 'avg_place': 4.410436137071651},
#  279: {'items': ['TFT_Item_BlueBuff', 'TFT_Item_ForceOfNature'],
#   'avg_place': 3.4545454545454546},
#  280: {'items': ['TFT_Item_BlueBuff', 'TFT_Item_GuinsoosRageblade'],
#   'avg_place': 4.576923076923077},
#  281: {'items': ['TFT_Item_BlueBuff',
#    'TFT_Item_GuinsoosRageblade',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.6153846153846154},
#  282: {'items': ['TFT_Item_BlueBuff', 'TFT_Item_HextechGunblade'],
#   'avg_place': 4.857142857142857},
#  283: {'items': ['TFT_Item_BlueBuff', 'TFT_Item_JeweledGauntlet'],
#   'avg_place': 4.594594594594595},
#  284: {'items': ['TFT_Item_BlueBuff',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_Leviathan'],
#   'avg_place': 4.258064516129032},
#  285: {'items': ['TFT_Item_BlueBuff',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_Morellonomicon'],
#   'avg_place': 4.461538461538462},
#  286: {'items': ['TFT_Item_BlueBuff',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 5.0},
#  287: {'items': ['TFT_Item_BlueBuff', 'TFT_Item_Leviathan'],
#   'avg_place': 4.379310344827586},
#  288: {'items': ['TFT_Item_BlueBuff',
#    'TFT_Item_Leviathan',
#    'TFT_Item_Morellonomicon'],
#   'avg_place': 3.111111111111111},
#  289: {'items': ['TFT_Item_BlueBuff',
#    'TFT_Item_Leviathan',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.7857142857142856},
#  290: {'items': ['TFT_Item_BlueBuff',
#    'TFT_Item_Leviathan',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.12},
#  291: {'items': ['TFT_Item_BlueBuff',
#    'TFT_Item_Leviathan',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 2.2727272727272725},
#  292: {'items': ['TFT_Item_BlueBuff', 'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 2.689655172413793},
#  293: {'items': ['TFT_Item_BlueBuff', 'TFT_Item_Moonstone'], 'avg_place': 3.5},
#  294: {'items': ['TFT_Item_BlueBuff', 'TFT_Item_Morellonomicon'],
#   'avg_place': 4.229166666666667},
#  295: {'items': ['TFT_Item_BlueBuff',
#    'TFT_Item_Morellonomicon',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.090909090909091},
#  296: {'items': ['TFT_Item_BlueBuff',
#    'TFT_Item_Morellonomicon',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.75},
#  297: {'items': ['TFT_Item_BlueBuff', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 3.9473684210526314},
#  298: {'items': ['TFT_Item_BlueBuff', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.9166666666666665},
#  299: {'items': ['TFT_Item_BlueBuff',
#    'TFT_Item_RabadonsDeathcap',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 5.25},
#  300: {'items': ['TFT_Item_BlueBuff', 'TFT_Item_RapidFireCannon'],
#   'avg_place': 3.022222222222222},
#  301: {'items': ['TFT_Item_BlueBuff', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.204819277108434},
#  302: {'items': ['TFT_Item_BlueBuff', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.7142857142857144},
#  303: {'items': ['TFT_Item_BrambleVest'], 'avg_place': 4.061224489795919},
#  304: {'items': ['TFT_Item_Chalice'], 'avg_place': 4.945945945945946},
#  305: {'items': ['TFT_Item_Chalice', 'TFT_Item_JeweledGauntlet'],
#   'avg_place': 4.0},
#  306: {'items': ['TFT_Item_Chalice', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.25},
#  307: {'items': ['TFT_Item_Chalice', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.25},
#  308: {'items': ['TFT_Item_Chalice', 'TFT_Item_ZekesHerald'],
#   'avg_place': 3.1818181818181817},
#  309: {'items': ['TFT_Item_Crownguard'], 'avg_place': 3.8392857142857144},
#  310: {'items': ['TFT_Item_Deathblade'], 'avg_place': 3.8983050847457625},
#  311: {'items': ['TFT_Item_DragonsClaw'], 'avg_place': 3.893939393939394},
#  312: {'items': ['TFT_Item_EternalFlame'], 'avg_place': 4.549281314168377},
#  313: {'items': ['TFT_Item_EternalFlame', 'TFT_Item_GuinsoosRageblade'],
#   'avg_place': 4.142857142857142},
#  314: {'items': ['TFT_Item_EternalFlame', 'TFT_Item_JeweledGauntlet'],
#   'avg_place': 4.230769230769231},
#  315: {'items': ['TFT_Item_EternalFlame', 'TFT_Item_Leviathan'],
#   'avg_place': 4.0},
#  316: {'items': ['TFT_Item_EternalFlame', 'TFT_Item_Moonstone'],
#   'avg_place': 3.625},
#  317: {'items': ['TFT_Item_EternalFlame', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 5.166666666666667},
#  318: {'items': ['TFT_Item_EternalFlame', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.055555555555555},
#  319: {'items': ['TFT_Item_EternalFlame', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.59375},
#  320: {'items': ['TFT_Item_EternalFlame', 'TFT_Item_StatikkShiv'],
#   'avg_place': 4.518518518518518},
#  321: {'items': ['TFT_Item_ForceOfNature'], 'avg_place': 3.8158614402917044},
#  322: {'items': ['TFT_Item_ForceOfNature', 'TFT_Item_ForceOfNature'],
#   'avg_place': 2.526315789473684},
#  323: {'items': ['TFT_Item_ForceOfNature', 'TFT_Item_JeweledGauntlet'],
#   'avg_place': 3.7777777777777777},
#  324: {'items': ['TFT_Item_ForceOfNature', 'TFT_Item_Leviathan'],
#   'avg_place': 2.642857142857143},
#  325: {'items': ['TFT_Item_ForceOfNature', 'TFT_Item_Moonstone'],
#   'avg_place': 3.1818181818181817},
#  326: {'items': ['TFT_Item_ForceOfNature', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.2727272727272725},
#  327: {'items': ['TFT_Item_ForceOfNature', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 2.92},
#  328: {'items': ['TFT_Item_ForceOfNature', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.64},
#  329: {'items': ['TFT_Item_FrozenHeart'], 'avg_place': 3.825242718446602},
#  330: {'items': ['TFT_Item_GargoyleStoneplate'],
#   'avg_place': 4.369565217391305},
#  331: {'items': ['TFT_Item_GuardianAngel'], 'avg_place': 3.4705882352941178},
#  332: {'items': ['TFT_Item_GuinsoosRageblade'],
#   'avg_place': 4.576660988074957},
#  333: {'items': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_GuinsoosRageblade'],
#   'avg_place': 5.338983050847458},
#  334: {'items': ['TFT_Item_GuinsoosRageblade',
#    'TFT_Item_GuinsoosRageblade',
#    'TFT_Item_GuinsoosRageblade'],
#   'avg_place': 4.7407407407407405},
#  335: {'items': ['TFT_Item_GuinsoosRageblade',
#    'TFT_Item_GuinsoosRageblade',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.423076923076923},
#  336: {'items': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_HextechGunblade'],
#   'avg_place': 4.363636363636363},
#  337: {'items': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_JeweledGauntlet'],
#   'avg_place': 4.655172413793103},
#  338: {'items': ['TFT_Item_GuinsoosRageblade',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_Leviathan'],
#   'avg_place': 4.142857142857142},
#  339: {'items': ['TFT_Item_GuinsoosRageblade',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.691666666666666},
#  340: {'items': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_LastWhisper'],
#   'avg_place': 6.63157894736842},
#  341: {'items': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_Leviathan'],
#   'avg_place': 4.1692307692307695},
#  342: {'items': ['TFT_Item_GuinsoosRageblade',
#    'TFT_Item_Leviathan',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.078260869565217},
#  343: {'items': ['TFT_Item_GuinsoosRageblade',
#    'TFT_Item_Leviathan',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.2},
#  344: {'items': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 4.7},
#  345: {'items': ['TFT_Item_GuinsoosRageblade',
#    'TFT_Item_MadredsBloodrazor',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.611111111111111},
#  346: {'items': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_Morellonomicon'],
#   'avg_place': 4.0144927536231885},
#  347: {'items': ['TFT_Item_GuinsoosRageblade',
#    'TFT_Item_Morellonomicon',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.15},
#  348: {'items': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 4.583333333333333},
#  349: {'items': ['TFT_Item_GuinsoosRageblade',
#    'TFT_Item_PowerGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.461538461538462},
#  350: {'items': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.3589743589743595},
#  351: {'items': ['TFT_Item_GuinsoosRageblade',
#    'TFT_Item_RabadonsDeathcap',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.918918918918919},
#  352: {'items': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_RapidFireCannon'],
#   'avg_place': 4.349206349206349},
#  353: {'items': ['TFT_Item_GuinsoosRageblade',
#    'TFT_Item_RapidFireCannon',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.368421052631579},
#  354: {'items': ['TFT_Item_GuinsoosRageblade',
#    'TFT_Item_RapidFireCannon',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.4166666666666665},
#  355: {'items': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.689655172413794},
#  356: {'items': ['TFT_Item_GuinsoosRageblade',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.166666666666667},
#  357: {'items': ['TFT_Item_GuinsoosRageblade',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 4.171428571428572},
#  358: {'items': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_StatikkShiv'],
#   'avg_place': 4.1875},
#  359: {'items': ['TFT_Item_HextechGunblade'], 'avg_place': 4.570135746606335},
#  360: {'items': ['TFT_Item_HextechGunblade', 'TFT_Item_JeweledGauntlet'],
#   'avg_place': 5.0},
#  361: {'items': ['TFT_Item_HextechGunblade',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.153846153846153},
#  362: {'items': ['TFT_Item_HextechGunblade', 'TFT_Item_Leviathan'],
#   'avg_place': 4.466666666666667},
#  363: {'items': ['TFT_Item_HextechGunblade',
#    'TFT_Item_Leviathan',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.1176470588235294},
#  364: {'items': ['TFT_Item_HextechGunblade', 'TFT_Item_RapidFireCannon'],
#   'avg_place': 5.0},
#  365: {'items': ['TFT_Item_HextechGunblade', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.25},
#  366: {'items': ['TFT_Item_HextechGunblade', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.8518518518518516},
#  367: {'items': ['TFT_Item_InfinityEdge'], 'avg_place': 4.88235294117647},
#  368: {'items': ['TFT_Item_InfinityEdge', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.5454545454545454},
#  369: {'items': ['TFT_Item_IonicSpark'], 'avg_place': 3.6285714285714286},
#  370: {'items': ['TFT_Item_JeweledGauntlet'], 'avg_place': 4.388091216216217},
#  371: {'items': ['TFT_Item_JeweledGauntlet', 'TFT_Item_JeweledGauntlet'],
#   'avg_place': 3.5660377358490565},
#  372: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 3.5},
#  373: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_JeweledGauntlet',
#    'TFT_Item_PowerGauntlet'],
#   'avg_place': 4.0},
#  374: {'items': ['TFT_Item_JeweledGauntlet', 'TFT_Item_Leviathan'],
#   'avg_place': 4.360975609756098},
#  375: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_Leviathan',
#    'TFT_Item_Leviathan'],
#   'avg_place': 3.727272727272727},
#  376: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_Leviathan',
#    'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 4.095238095238095},
#  377: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_Leviathan',
#    'TFT_Item_Morellonomicon'],
#   'avg_place': 4.176470588235294},
#  378: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_Leviathan',
#    'TFT_Item_PowerGauntlet'],
#   'avg_place': 3.84},
#  379: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_Leviathan',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.7333333333333334},
#  380: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_Leviathan',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.592987804878049},
#  381: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_Leviathan',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.5},
#  382: {'items': ['TFT_Item_JeweledGauntlet', 'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 3.9933333333333336},
#  383: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_MadredsBloodrazor',
#    'TFT_Item_PowerGauntlet'],
#   'avg_place': 3.928571428571429},
#  384: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_MadredsBloodrazor',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.111111111111111},
#  385: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_MadredsBloodrazor',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.0},
#  386: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_MadredsBloodrazor',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.3846153846153846},
#  387: {'items': ['TFT_Item_JeweledGauntlet', 'TFT_Item_Moonstone'],
#   'avg_place': 4.944444444444445},
#  388: {'items': ['TFT_Item_JeweledGauntlet', 'TFT_Item_Morellonomicon'],
#   'avg_place': 4.0256410256410255},
#  389: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_Morellonomicon',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.725},
#  390: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_Morellonomicon',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.6363636363636362},
#  391: {'items': ['TFT_Item_JeweledGauntlet', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 3.977443609022556},
#  392: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_PowerGauntlet',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.2},
#  393: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_PowerGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.609756097560975},
#  394: {'items': ['TFT_Item_JeweledGauntlet', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.124031007751938},
#  395: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_RabadonsDeathcap',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.292307692307692},
#  396: {'items': ['TFT_Item_JeweledGauntlet', 'TFT_Item_RapidFireCannon'],
#   'avg_place': 4.517241379310345},
#  397: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_RapidFireCannon',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.309523809523809},
#  398: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_RapidFireCannon',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.25},
#  399: {'items': ['TFT_Item_JeweledGauntlet', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.598540145985401},
#  400: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.810810810810811},
#  401: {'items': ['TFT_Item_JeweledGauntlet',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.65625},
#  402: {'items': ['TFT_Item_JeweledGauntlet', 'TFT_Item_StatikkShiv'],
#   'avg_place': 4.26595744680851},
#  403: {'items': ['TFT_Item_LastWhisper'], 'avg_place': 4.240641711229946},
#  404: {'items': ['TFT_Item_LastWhisper', 'TFT_Item_Morellonomicon'],
#   'avg_place': 4.384615384615385},
#  405: {'items': ['TFT_Item_LastWhisper', 'TFT_Item_RapidFireCannon'],
#   'avg_place': 4.0},
#  406: {'items': ['TFT_Item_LastWhisper', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.56},
#  407: {'items': ['TFT_Item_LastWhisper', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.7368421052631575},
#  408: {'items': ['TFT_Item_Leviathan'], 'avg_place': 4.300701754385965},
#  409: {'items': ['TFT_Item_Leviathan', 'TFT_Item_Leviathan'],
#   'avg_place': 3.745762711864407},
#  410: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_Leviathan',
#    'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 3.6363636363636362},
#  411: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_Leviathan',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.12},
#  412: {'items': ['TFT_Item_Leviathan', 'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 4.10828025477707},
#  413: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_MadredsBloodrazor',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.142857142857143},
#  414: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_MadredsBloodrazor',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.9393939393939394},
#  415: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_MadredsBloodrazor',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.1538461538461537},
#  416: {'items': ['TFT_Item_Leviathan', 'TFT_Item_Moonstone'],
#   'avg_place': 3.3636363636363638},
#  417: {'items': ['TFT_Item_Leviathan', 'TFT_Item_Morellonomicon'],
#   'avg_place': 4.015384615384615},
#  418: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_Morellonomicon',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.1866666666666665},
#  419: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_Morellonomicon',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.769230769230769},
#  420: {'items': ['TFT_Item_Leviathan', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 3.8295454545454546},
#  421: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_PowerGauntlet',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.25},
#  422: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_PowerGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.583333333333333},
#  423: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_PowerGauntlet',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.8125},
#  424: {'items': ['TFT_Item_Leviathan', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.076470588235294},
#  425: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_RabadonsDeathcap',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.0},
#  426: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_RabadonsDeathcap',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.481060606060606},
#  427: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_RabadonsDeathcap',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.2},
#  428: {'items': ['TFT_Item_Leviathan', 'TFT_Item_RapidFireCannon'],
#   'avg_place': 3.95},
#  429: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_RapidFireCannon',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.775},
#  430: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_RapidFireCannon',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 2.6923076923076925},
#  431: {'items': ['TFT_Item_Leviathan', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.463483146067416},
#  432: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.4054054054054057},
#  433: {'items': ['TFT_Item_Leviathan',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.402173913043478},
#  434: {'items': ['TFT_Item_Leviathan', 'TFT_Item_StatikkShiv'],
#   'avg_place': 4.0134228187919465},
#  435: {'items': ['TFT_Item_Leviathan', 'TFT_Item_ZekesHerald'],
#   'avg_place': 4.0},
#  436: {'items': ['TFT_Item_LocketOfTheIronSolari'], 'avg_place': 3.5},
#  437: {'items': ['TFT_Item_MadredsBloodrazor'],
#   'avg_place': 4.271005342399223},
#  438: {'items': ['TFT_Item_MadredsBloodrazor', 'TFT_Item_MadredsBloodrazor'],
#   'avg_place': 3.6491228070175437},
#  439: {'items': ['TFT_Item_MadredsBloodrazor', 'TFT_Item_Morellonomicon'],
#   'avg_place': 4.6},
#  440: {'items': ['TFT_Item_MadredsBloodrazor',
#    'TFT_Item_Morellonomicon',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.882352941176471},
#  441: {'items': ['TFT_Item_MadredsBloodrazor', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 4.0588235294117645},
#  442: {'items': ['TFT_Item_MadredsBloodrazor',
#    'TFT_Item_PowerGauntlet',
#    'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.928571428571429},
#  443: {'items': ['TFT_Item_MadredsBloodrazor',
#    'TFT_Item_PowerGauntlet',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.555555555555555},
#  444: {'items': ['TFT_Item_MadredsBloodrazor', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.074324324324325},
#  445: {'items': ['TFT_Item_MadredsBloodrazor',
#    'TFT_Item_RabadonsDeathcap',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.555555555555555},
#  446: {'items': ['TFT_Item_MadredsBloodrazor', 'TFT_Item_RapidFireCannon'],
#   'avg_place': 3.6818181818181817},
#  447: {'items': ['TFT_Item_MadredsBloodrazor', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.989130434782609},
#  448: {'items': ['TFT_Item_MadredsBloodrazor',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.318181818181818},
#  449: {'items': ['TFT_Item_MadredsBloodrazor', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.767857142857143},
#  450: {'items': ['TFT_Item_Moonstone'], 'avg_place': 4.008777852802161},
#  451: {'items': ['TFT_Item_Moonstone', 'TFT_Item_Moonstone'],
#   'avg_place': 3.2857142857142856},
#  452: {'items': ['TFT_Item_Moonstone', 'TFT_Item_Morellonomicon'],
#   'avg_place': 4.076923076923077},
#  453: {'items': ['TFT_Item_Moonstone', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 3.6666666666666665},
#  454: {'items': ['TFT_Item_Moonstone', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.5},
#  455: {'items': ['TFT_Item_Moonstone', 'TFT_Item_RapidFireCannon'],
#   'avg_place': 3.2857142857142856},
#  456: {'items': ['TFT_Item_Moonstone', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.5},
#  457: {'items': ['TFT_Item_Moonstone', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.303571428571429},
#  458: {'items': ['TFT_Item_Morellonomicon'], 'avg_place': 4.42931688804554},
#  459: {'items': ['TFT_Item_Morellonomicon', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 4.19047619047619},
#  460: {'items': ['TFT_Item_Morellonomicon', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 4.275},
#  461: {'items': ['TFT_Item_Morellonomicon',
#    'TFT_Item_RabadonsDeathcap',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.678571428571429},
#  462: {'items': ['TFT_Item_Morellonomicon', 'TFT_Item_RapidFireCannon'],
#   'avg_place': 4.615384615384616},
#  463: {'items': ['TFT_Item_Morellonomicon', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.026431718061674},
#  464: {'items': ['TFT_Item_Morellonomicon',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.533333333333333},
#  465: {'items': ['TFT_Item_Morellonomicon',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.6666666666666665},
#  466: {'items': ['TFT_Item_Morellonomicon', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.8098591549295775},
#  467: {'items': ['TFT_Item_Morellonomicon', 'TFT_Item_ZekesHerald'],
#   'avg_place': 5.866666666666667},
#  468: {'items': ['TFT_Item_NightHarvester'], 'avg_place': 4.0},
#  469: {'items': ['TFT_Item_PowerGauntlet'], 'avg_place': 4.303525804803271},
#  470: {'items': ['TFT_Item_PowerGauntlet', 'TFT_Item_PowerGauntlet'],
#   'avg_place': 4.12987012987013},
#  471: {'items': ['TFT_Item_PowerGauntlet', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.976923076923077},
#  472: {'items': ['TFT_Item_PowerGauntlet',
#    'TFT_Item_RabadonsDeathcap',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.6818181818181817},
#  473: {'items': ['TFT_Item_PowerGauntlet', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.146892655367232},
#  474: {'items': ['TFT_Item_PowerGauntlet',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.5384615384615383},
#  475: {'items': ['TFT_Item_PowerGauntlet',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.4736842105263155},
#  476: {'items': ['TFT_Item_PowerGauntlet', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.9333333333333336},
#  477: {'items': ['TFT_Item_Quicksilver'], 'avg_place': 3.813953488372093},
#  478: {'items': ['TFT_Item_RabadonsDeathcap'], 'avg_place': 4.348978704910908},
#  479: {'items': ['TFT_Item_RabadonsDeathcap', 'TFT_Item_RabadonsDeathcap'],
#   'avg_place': 3.831168831168831},
#  480: {'items': ['TFT_Item_RabadonsDeathcap', 'TFT_Item_RapidFireCannon'],
#   'avg_place': 4.5625},
#  481: {'items': ['TFT_Item_RabadonsDeathcap',
#    'TFT_Item_RapidFireCannon',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.555555555555555},
#  482: {'items': ['TFT_Item_RabadonsDeathcap', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.251282051282051},
#  483: {'items': ['TFT_Item_RabadonsDeathcap',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_SpearOfShojin'],
#   'avg_place': 3.84},
#  484: {'items': ['TFT_Item_RabadonsDeathcap',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.709677419354839},
#  485: {'items': ['TFT_Item_RabadonsDeathcap', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.8313253012048194},
#  486: {'items': ['TFT_Item_RadiantVirtue'], 'avg_place': 4.55241935483871},
#  487: {'items': ['TFT_Item_RapidFireCannon'], 'avg_place': 4.2938311688311686},
#  488: {'items': ['TFT_Item_RapidFireCannon', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.206106870229007},
#  489: {'items': ['TFT_Item_RapidFireCannon',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.5},
#  490: {'items': ['TFT_Item_RapidFireCannon', 'TFT_Item_StatikkShiv'],
#   'avg_place': 4.009615384615385},
#  491: {'items': ['TFT_Item_RedBuff'], 'avg_place': 4.236363636363636},
#  492: {'items': ['TFT_Item_Redemption'], 'avg_place': 3.8344827586206898},
#  493: {'items': ['TFT_Item_RunaansHurricane'], 'avg_place': 4.169398907103825},
#  494: {'items': ['TFT_Item_RunaansHurricane', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.6923076923076925},
#  495: {'items': ['TFT_Item_RunaansHurricane', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.0},
#  496: {'items': ['TFT_Item_Shroud'], 'avg_place': 4.535294117647059},
#  497: {'items': ['TFT_Item_SpearOfShojin'], 'avg_place': 4.460904522613065},
#  498: {'items': ['TFT_Item_SpearOfShojin', 'TFT_Item_SpearOfShojin'],
#   'avg_place': 4.0928571428571425},
#  499: {'items': ['TFT_Item_SpearOfShojin',
#    'TFT_Item_SpearOfShojin',
#    'TFT_Item_StatikkShiv'],
#   'avg_place': 3.9047619047619047},
#  500: {'items': ['TFT_Item_SpearOfShojin', 'TFT_Item_StatikkShiv'],
#   'avg_place': 4.090252707581228},
#  501: {'items': ['TFT_Item_SpearOfShojin', 'TFT_Item_ZekesHerald'],
#   'avg_place': 4.291666666666667},
#  502: {'items': ['TFT_Item_SpearOfShojin', 'TFT_Item_Zephyr'],
#   'avg_place': 3.75},
#  503: {'items': ['TFT_Item_SpectralGauntlet'],
#   'avg_place': 3.7714285714285714},
#  504: {'items': ['TFT_Item_Spite'], 'avg_place': 5.26530612244898},
#  505: {'items': ['TFT_Item_StatikkShiv'], 'avg_place': 3.9560411311053985},
#  506: {'items': ['TFT_Item_StatikkShiv', 'TFT_Item_StatikkShiv'],
#   'avg_place': 3.48},
#  507: {'items': ['TFT_Item_StatikkShiv', 'TFT_Item_ZekesHerald'],
#   'avg_place': 3.0},
#  508: {'items': ['TFT_Item_SteraksGage'], 'avg_place': 4.933333333333334},
#  509: {'items': ['TFT_Item_SupportKnightsVow'],
#   'avg_place': 4.915254237288136},
#  510: {'items': ['TFT_Item_ThiefsGloves'], 'avg_place': 4.0218508997429305},
#  511: {'items': ['TFT_Item_TitansResolve'], 'avg_place': 4.533333333333333},
#  512: {'items': ['TFT_Item_UnstableConcoction'],
#   'avg_place': 4.063063063063063},
#  513: {'items': ['TFT_Item_UnstableTreasureChest'],
#   'avg_place': 5.298701298701299},
#  514: {'items': ['TFT_Item_UnstableTreasureChest',
#    'TFT_Item_UnstableTreasureChest'],
#   'avg_place': 3.4259259259259256},
#  515: {'items': ['TFT_Item_WarmogsArmor'], 'avg_place': 4.333333333333333},
#  516: {'items': ['TFT_Item_ZekesHerald'], 'avg_place': 4.553695955369595},
#  517: {'items': ['TFT_Item_Zephyr'], 'avg_place': 4.259770114942529}}
